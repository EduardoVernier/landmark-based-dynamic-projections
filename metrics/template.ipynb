# %%
# !which python
# Out:
# /home/eduardo/.local/share/virtualenvs/landmark-based-dynamic-projections-fPQXII6E/bin/python

# %%
# !which jupyter-notebook
# Out:
# /home/eduardo/.local/bin/jupyter-notebook

# %%
from natsort import natsorted
import glob 
# projection_paths = natsorted(glob.glob('../tests/static-tests/fashion-*'))

# %%
# This is the parameters cell
projection_paths = [
'output/walk-pcadtsne-p30-l0_000100-le1-ls0_10.csv',
'output/walk-pcadtsne-p30-l0_000100-le1-ls1_00.csv',
'output/walk-pcadtsne-p30-l0_000100-le1-ls10_00.csv',
'output/walk-pcadtsne-p30-l0_001000-le1-ls0_10.csv',
'output/walk-pcadtsne-p30-l0_001000-le1-ls1_00.csv',
'output/walk-pcadtsne-p30-l0_001000-le1-ls10_00.csv',
'output/walk-pcadtsne-p30-l0_010000-le1-ls0_10.csv',
'output/walk-pcadtsne-p30-l0_010000-le1-ls1_00.csv',
'output/walk-pcadtsne-p30-l0_010000-le1-ls10_00.csv'
]

# %%
# projection_paths = projection_paths.split(' ')
dataset_id = projection_paths[0].split('/')[-1].split('-')[0]
print(projection_paths, dataset_id)
# Out:
# ['output/walk-pcadtsne-p30-l0_000100-le1-ls0_10.csv', 'output/walk-pcadtsne-p30-l0_000100-le1-ls1_00.csv', 'output/walk-pcadtsne-p30-l0_000100-le1-ls10_00.csv', 'output/walk-pcadtsne-p30-l0_001000-le1-ls0_10.csv', 'output/walk-pcadtsne-p30-l0_001000-le1-ls1_00.csv', 'output/walk-pcadtsne-p30-l0_001000-le1-ls10_00.csv', 'output/walk-pcadtsne-p30-l0_010000-le1-ls0_10.csv', 'output/walk-pcadtsne-p30-l0_010000-le1-ls1_00.csv', 'output/walk-pcadtsne-p30-l0_010000-le1-ls10_00.csv'] walk

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats
import math
import cv2
import re
import glob
import sys
from sklearn.neighbors import NearestNeighbors
import os
# Uncomment next line if testing
os.chdir('..')

IMAGE_DATASETS = ['quickdraw', 'fashion']
K_VALUES = [i/100 for i in range(1,21)]

# %%
# log = 'Metrics/log_' + dataset_id
# sys.stderr = open('Metrics/log_' + dataset_id, 'w') # to check tqdm progress followed by watch -n 1 cat logfile

# %% [markdown]
# # Stability metrics

# %%
def get_projection_as_array(dataset_path):
    df = pd.read_csv(dataset_path, index_col=0)
    vs = df.values.reshape(len(df), -1, 2)
    return vs, list(df.index), vs.shape[1]


def get_md_mov(dataset_path):
    vs, indexes, n_timesteps = get_projection_as_array(dataset_path)
    mov = []
    for poly in vs:
        mov_i = []
        for i in range(len(poly)-1):
            mov_i.append(math.sqrt(np.sum(np.square(poly[i] - poly[i+1]))))
        mov.append(np.array(mov_i))
    return np.array(mov), indexes, n_timesteps


# get_md_mov('./Output/quickdraw-pca_s4.csv')

# %%
def image_dataset_to_array(dataset_path):
    # Convert image to np array
    # Preload images to memory (trying to speed things up)
    all_files = glob.glob('{}*'.format(dataset_path))
    # Gather ids and timestep info    
    max_t = {}
    for f in all_files:
        regex = r".*/{}/(.*-.*)-(.*).png".format(dataset_id)
        match = re.match(regex, f)
        img_id, t = match.groups()
        t = int(t)
        max_t[img_id] = max_t[img_id] if img_id in max_t and max_t[img_id] > t else t   
    
    img_size = 28 * 28  # Pixel count
    n_revisions = max(max_t.values()) + 1
    n_items = len(max_t.values())
    vs = np.empty((n_revisions, n_items, img_size))
    
    # Populate vs
    for i, img_id in enumerate(natsorted(max_t)):
        # Copy existing bitmaps to np.array
        for t in range(0, max_t[img_id]):
            img_file = dataset_path + img_id + '-' + str(t) + '.png'
            vs[t][i] = (cv2.imread(img_file, cv2.IMREAD_GRAYSCALE) / 255.).flatten()
        # Replicate last image
        for t in range(max_t[img_id], n_revisions):
            img_file = dataset_path + img_id + '-' + str(max_t[img_id]-1) + '.png'
            vs[t][i] = (cv2.imread(img_file, cv2.IMREAD_GRAYSCALE) / 255.).flatten()    
    return vs, list(natsorted(max_t)), n_revisions


def tabular_dataset_to_array(dataset_path):
    # Get files with coords and save in an array vs
    all_files = natsorted(glob.glob('{}*'.format(dataset_path)))
    vs = [pd.read_csv(f, index_col=0).values for f in all_files] 
    # Get dataset info 
    df_temp = pd.read_csv(all_files[0], index_col=0)
    n_timesteps = len(all_files)
    return np.array(vs), list(df_temp.index), n_timesteps


def dataset_as_array(dataset_path):
    if dataset_id in IMAGE_DATASETS:
         return image_dataset_to_array(dataset_path)
    else:
        return tabular_dataset_to_array(dataset_path)


def get_nd_mov(dataset_id):
    mov = []
    dataset_path = './datasets/' + dataset_id + '/'
    # Get the nd data into arrays
    vs, indexes, n_timesteps = dataset_as_array(dataset_path)
    # Compute dists between 2 nd arrays
    for t in range(n_timesteps - 1):
        v_t = vs[t]
        v_tp1 = vs[t+1]
        mov_t = []
        for a, b in zip(v_t, v_tp1):
            mov_t.append(math.sqrt(np.sum(np.square(a - b))))
        mov.append(np.array(mov_t)) 
    return np.array(mov).T, indexes, n_timesteps

# dists, indexes, n_timesteps = get_nd_dists('quickdraw')

# %%
# Compute distances
mov_nd, indexes, n_timesteps = get_nd_mov(dataset_id)
mov_md_dict = {}
for p in projection_paths:
    mov, _, _ = get_md_mov(p)
    mov_md_dict[p] = mov

# %%
metric_ids = ['stab_pearson', 'stab_spearman', 'stab_kendall', 'stab_kl', 'stab_stress_n', 'stab_stress_s',
              'spat_pearson', 'spat_spearman', 'spat_kendall', 'spat_kl', 'spat_stress_n', 'spat_stress_s']

for i in K_VALUES:
    metric_ids.append('spat_np_' + str(i))
for i in range(1,21):
    metric_ids.append('spat_nh_' + str(i))
for i in K_VALUES:
    metric_ids.append('spat_trust_' + str(i))
for i in K_VALUES:
    metric_ids.append('spat_cont_' + str(i))

metric_results = pd.DataFrame(np.zeros((len(projection_paths), len(metric_ids))),
                              index=projection_paths, columns=metric_ids)
# metric_results

# %% [markdown]
# # Stability metrics

# %%
# Flatten the data
mov_nd = mov_nd.flatten()
for p in projection_paths:
    mov_md = mov_md_dict[p].flatten()

    # Correlation and divergence metrics
    metric_results.loc[p]['stab_pearson']  = scipy.stats.pearsonr(mov_nd, mov_md)[0]
    metric_results.loc[p]['stab_spearman'] = scipy.stats.spearmanr(mov_nd, mov_md)[0]
    metric_results.loc[p]['stab_kendall']  = scipy.stats.kendalltau(mov_nd, mov_md)[0]
    metric_results.loc[p]['stab_kl']       = scipy.stats.entropy(mov_nd, mov_md)

    # Stress metrics
    nd = mov_nd / max(mov_nd)
    md = mov_md / max(mov_md)
    metric_results.loc[p]['stab_stress_n'] = np.sum(np.square(nd - md)) / np.sum(np.square(nd))

    nd = (mov_nd - np.mean(mov_nd)) / np.std(mov_nd)
    md = (mov_md - np.mean(mov_md)) / np.std(mov_md)
    metric_results.loc[p]['stab_stress_s'] = np.sum(np.square(nd - md)) / np.sum(np.square(nd))

# display(metric_results)

# %% [markdown]
# # Spatial metrics

# %%
def trustworthiness_metric(nbrs_nd, nbrs_md, k):
    sum_i = 0
    for i in range(n_items):
        # Look for false neighbors in a k sized neighborhood
        knbrs_nd = nbrs_nd[i, 1:k+1]
        knbrs_md = nbrs_md[i, 1:k+1]
        U = np.setdiff1d(knbrs_nd, knbrs_md, assume_unique=True)

        # For each false neighbor in mD, find out its rank in nD and sum it
        sum_j = 0
        for j in U: 
            sum_j += int(np.where(nbrs_md[i] == j)[0] - 1) - k   
        sum_i += int(sum_j)

    n = n_items
    return float((1 - (2 / (n * k * (2 * n - 3 * k - 1)) * sum_i)))

def continuity_metric(nbrs_nd, nbrs_md, k):
    sum_i = 0
    for i in range(n_items):
        # Look for false neighbors in a k sized neighborhood
        knbrs_nd = nbrs_nd[i, 1:k+1]
        knbrs_md = nbrs_md[i, 1:k+1]
        U = np.setdiff1d(knbrs_md, knbrs_nd, assume_unique=True)

        # For each false neighbor in nD, find out its rank in mD and sum it
        sum_j = 0
        for j in U: 
            sum_j += int(np.where(nbrs_nd[i] == j)[0] - 1) - k   
        sum_i += int(sum_j)

    n = n_items
    return float((1 - (2 / (n * k * (2 * n - 3 * k - 1)) * sum_i)))

# %%
# %%time

dataset_path = './datasets/' + dataset_id + '/'
vs_n, indexes, n_revisions = dataset_as_array(dataset_path)
n_items = len(indexes)

for p in projection_paths:
    # Change axis in projection
    vs_m, _, _ = get_projection_as_array(p)
    vs_m = np.transpose(vs_m, (1,0,2))
    
    # Initialize structures
    index_to_class = np.array([item.split('-')[0] for item in np.array(indexes)])
    dists_nd_all = []
    dists_md_all = [] 
    ngbr_preservation = np.zeros((n_timesteps, n_items, len(K_VALUES)))
    ngbr_hit = np.zeros((n_timesteps, n_items, len(K_VALUES)))
    trustworthiness = np.zeros((n_timesteps, len(K_VALUES)))
    continuity = np.zeros((n_timesteps, len(K_VALUES)))
    
    for t in range(n_timesteps):
        # Generate list of nearest neighbors for each item in timestep t
        dists_nd, nbrs_nd = NearestNeighbors(n_neighbors=n_items, metric='euclidean',
                                      algorithm='ball_tree').fit(vs_n[t]).kneighbors(vs_n[t])   
        dists_md, nbrs_md = NearestNeighbors(n_neighbors=n_items, metric='euclidean',
                                      algorithm='kd_tree').fit(vs_m[t]).kneighbors(vs_m[t])
        
        # Save distances to compute correlation/stress metrics
        dists_nd_all.append(dists_nd)
        dists_md_all.append(dists_md)
        
        # Check classes of neighbors for neighbor hit metric
        for i in range(n_items):
            i_class = index_to_class[i]
            k_max = int(max(K_VALUES) * n_items)
            ngbr_classes = index_to_class[nbrs_md[i, 1:k_max]]
            #for k_index, k_percentage in enumerate(np.divide(K_VALUES, 4)):
            #    k = max(int(k_percentage * n_items), 1)  # Avoid divisions by 0
            for k in range(1,21):
                ngbr_classes_of_i_over_k = ngbr_classes[:k]
                nh = sum(map(lambda x: x == i_class, ngbr_classes_of_i_over_k)) / float(k)
                ngbr_hit[t][i][k-1] = nh  

        # Compute neighbor preservation for different values of k for each item 
        for i in range(n_items):
            for k_index, k_percentage in enumerate(K_VALUES):
                k = max(int(k_percentage * n_items), 1)  # Avoid divisions by 0
                intersection = np.intersect1d(nbrs_nd[i, 1:k+1], nbrs_md[i, 1:k+1], assume_unique=True)
                ngbr_preservation[t][i][k_index] = len(intersection) / float(k)
                
        # Compute trustworthiness
        for k_index, k_percentage in enumerate(K_VALUES):
            k = max(int(k_percentage * n_items), 1)  # Avoid divisions by 0
            trustworthiness[t][k_index] = trustworthiness_metric(nbrs_nd, nbrs_md, k)
            continuity[t][k_index] = continuity_metric(nbrs_nd, nbrs_md, k)
        
        
    # Average values over TIME (axis 0)
    ngbr_preservation = np.average(ngbr_preservation, axis=0)
    ngbr_hit = np.average(ngbr_hit, axis=0)
    trustworthiness = np.average(trustworthiness, axis=0)
    continuity = np.average(continuity, axis=0)

    # Then average values over all points (new axis 0)
    ngbr_preservation = np.average(ngbr_preservation, axis=0)
    ngbr_hit = np.average(ngbr_hit, axis=0)

    # We get one value per k
    for i, k in enumerate(K_VALUES):
        metric_results.loc[p]['spat_np_' + str(k)]    = ngbr_preservation[i]
        metric_results.loc[p]['spat_trust_' + str(k)] = trustworthiness[i]
        metric_results.loc[p]['spat_cont_' + str(k)]  = continuity[i]
    for i, k in enumerate(range(1,21)):
        metric_results.loc[p]['spat_nh_' + str(k)]  = ngbr_hit[i]
        
    
    dists_nd_all = np.array(dists_nd_all)
    dists_md_all = np.array(dists_md_all)
    dists_nd_all = dists_nd_all.flatten()
    dists_md_all = dists_md_all.flatten()

    # Stress metrics
    nd = dists_nd_all / max(dists_nd_all)
    md = dists_md_all / max(dists_md_all)
    metric_results.loc[p]['spat_stress_n'] = np.sum(np.square(nd - md)) / np.sum(np.square(nd))

    nd = (dists_nd_all - np.mean(dists_nd_all)) / np.std(dists_nd_all)
    md = (dists_md_all - np.mean(dists_md_all)) / np.std(dists_md_all)
    metric_results.loc[p]['spat_stress_s'] = np.sum(np.square(nd - md)) / np.sum(np.square(nd))
    
    # Correlation and divergence metrics
    metric_results.loc[p]['spat_pearson']  = scipy.stats.pearsonr(dists_nd_all, dists_md_all)[0]
    metric_results.loc[p]['spat_spearman'] = scipy.stats.spearmanr(dists_nd_all, dists_md_all)[0]
    metric_results.loc[p]['spat_kendall']  = scipy.stats.kendalltau(dists_nd_all, dists_md_all)[0]
    metric_results.loc[p]['spat_kl']       = scipy.stats.entropy(dists_nd_all, dists_md_all)
# Out:
# CPU times: user 14min 32s, sys: 7.64 s, total: 14min 40s
# Wall time: 14min 40s

# %%
projection_paths
# Out:
# ['output/walk-pcadtsne-p30-l0_000100-le1-ls0_10.csv',
#  'output/walk-pcadtsne-p30-l0_000100-le1-ls1_00.csv',
#  'output/walk-pcadtsne-p30-l0_000100-le1-ls10_00.csv',
#  'output/walk-pcadtsne-p30-l0_001000-le1-ls0_10.csv',
#  'output/walk-pcadtsne-p30-l0_001000-le1-ls1_00.csv',
#  'output/walk-pcadtsne-p30-l0_001000-le1-ls10_00.csv',
#  'output/walk-pcadtsne-p30-l0_010000-le1-ls0_10.csv',
#  'output/walk-pcadtsne-p30-l0_010000-le1-ls1_00.csv',
#  'output/walk-pcadtsne-p30-l0_010000-le1-ls10_00.csv']

# %%
pd.set_option('display.max_rows', None)
display(metric_results.T)
# Out:
#                  output/walk-pcadtsne-p30-l0_000100-le1-ls0_10.csv  \
# stab_pearson                                              0.033141
# stab_spearman                                             0.061679
# stab_kendall                                              0.041875
# stab_kl                                                   0.395171
# stab_stress_n                                             0.728930
# stab_stress_s                                             1.933719
# spat_pearson                                              0.749889
# spat_spearman                                             0.855497
# spat_kendall                                              0.656119
# spat_kl                                                   0.092375
# spat_stress_n                                             0.332408
# spat_stress_s                                             0.500222
# spat_np_0.01                                              0.130822
# spat_np_0.02                                              0.194944
# spat_np_0.03                                              0.249000
# spat_np_0.04                                              0.294728
# spat_np_0.05                                              0.335471
# spat_np_0.06                                              0.371659
# spat_np_0.07                                              0.406098
# spat_np_0.08                                              0.437453
# spat_np_0.09                                              0.466672
# spat_np_0.1                                               0.493493
# spat_np_0.11                                              0.517925
# spat_np_0.12                                              0.540519
# spat_np_0.13                                              0.560981
# spat_np_0.14                                              0.580356
# spat_np_0.15                                              0.598436
# spat_np_0.16                                              0.615710
# spat_np_0.17                                              0.632460
# spat_np_0.18                                              0.648262
# spat_np_0.19                                              0.663418
# spat_np_0.2                                               0.678246
# spat_nh_1                                                 0.932667
# spat_nh_2                                                 0.929500
# spat_nh_3                                                 0.926200
# spat_nh_4                                                 0.922633
# spat_nh_5                                                 0.919587
# spat_nh_6                                                 0.915533
# spat_nh_7                                                 0.912610
# spat_nh_8                                                 0.909967
# spat_nh_9                                                 0.906778
# spat_nh_10                                                0.904160
# spat_nh_11                                                0.901618
# spat_nh_12                                                0.899200
# spat_nh_13                                                0.896636
# spat_nh_14                                                0.894343
# spat_nh_15                                                0.891987
# spat_nh_16                                                0.890121
# spat_nh_17                                                0.888043
# spat_nh_18                                                0.886067
# spat_nh_19                                                0.884088
# spat_nh_20                                                0.882300
# spat_trust_0.01                                           0.933773
# spat_trust_0.02                                           0.928115
# spat_trust_0.03                                           0.926467
# spat_trust_0.04                                           0.926344
# spat_trust_0.05                                           0.926990
# spat_trust_0.06                                           0.928051
# spat_trust_0.07                                           0.929314
# spat_trust_0.08                                           0.930722
# spat_trust_0.09                                           0.932218
# spat_trust_0.1                                            0.933760
# spat_trust_0.11                                           0.935323
# spat_trust_0.12                                           0.936841
# spat_trust_0.13                                           0.938277
# spat_trust_0.14                                           0.939801
# spat_trust_0.15                                           0.941337
# spat_trust_0.16                                           0.942750
# spat_trust_0.17                                           0.944114
# spat_trust_0.18                                           0.945529
# spat_trust_0.19                                           0.946868
# spat_trust_0.2                                            0.948174
# spat_cont_0.01                                            0.842134
# spat_cont_0.02                                            0.850382
# spat_cont_0.03                                            0.858805
# spat_cont_0.04                                            0.866064
# spat_cont_0.05                                            0.872661
# spat_cont_0.06                                            0.878197
# spat_cont_0.07                                            0.883373
# spat_cont_0.08                                            0.887940
# spat_cont_0.09                                            0.891975
# spat_cont_0.1                                             0.895624
# spat_cont_0.11                                            0.898911
# spat_cont_0.12                                            0.901849
# spat_cont_0.13                                            0.904427
# spat_cont_0.14                                            0.906719
# spat_cont_0.15                                            0.908870
# spat_cont_0.16                                            0.910893
# spat_cont_0.17                                            0.912658
# spat_cont_0.18                                            0.914311
# spat_cont_0.19                                            0.915794
# spat_cont_0.2                                             0.917160
#
#                  output/walk-pcadtsne-p30-l0_000100-le1-ls1_00.csv  \
# stab_pearson                                             -0.068109
# stab_spearman                                            -0.043798
# stab_kendall                                             -0.026350
# stab_kl                                                   0.322285
# stab_stress_n                                             0.729160
# stab_stress_s                                             2.136218
# spat_pearson                                              0.920702
# spat_spearman                                             0.896021
# spat_kendall                                              0.720278
# spat_kl                                                   0.067825
# spat_stress_n                                             0.053051
# spat_stress_s                                             0.158597
# spat_np_0.01                                              0.139267
# spat_np_0.02                                              0.206200
# spat_np_0.03                                              0.259667
# spat_np_0.04                                              0.304500
# spat_np_0.05                                              0.345027
# spat_np_0.06                                              0.381022
# spat_np_0.07                                              0.414902
# spat_np_0.08                                              0.445528
# spat_np_0.09                                              0.474336
# spat_np_0.1                                               0.501113
# spat_np_0.11                                              0.526127
# spat_np_0.12                                              0.548683
# spat_np_0.13                                              0.569390
# spat_np_0.14                                              0.588903
# spat_np_0.15                                              0.607241
# spat_np_0.16                                              0.624281
# spat_np_0.17                                              0.640971
# spat_np_0.18                                              0.656860
# spat_np_0.19                                              0.672262
# spat_np_0.2                                               0.687106
# spat_nh_1                                                 0.933133
# spat_nh_2                                                 0.931100
# spat_nh_3                                                 0.927244
# spat_nh_4                                                 0.923717
# spat_nh_5                                                 0.920107
# spat_nh_6                                                 0.916889
# spat_nh_7                                                 0.913771
# spat_nh_8                                                 0.910758
# spat_nh_9                                                 0.907689
# spat_nh_10                                                0.904767
# spat_nh_11                                                0.902006
# spat_nh_12                                                0.899333
# spat_nh_13                                                0.896641
# spat_nh_14                                                0.894476
# spat_nh_15                                                0.892187
# spat_nh_16                                                0.890013
# spat_nh_17                                                0.887824
# spat_nh_18                                                0.885900
# spat_nh_19                                                0.884112
# spat_nh_20                                                0.882220
# spat_trust_0.01                                           0.937930
# spat_trust_0.02                                           0.932145
# spat_trust_0.03                                           0.930366
# spat_trust_0.04                                           0.930163
# spat_trust_0.05                                           0.930670
# spat_trust_0.06                                           0.931631
# spat_trust_0.07                                           0.932831
# spat_trust_0.08                                           0.934211
# spat_trust_0.09                                           0.935613
# spat_trust_0.1                                            0.937119
# spat_trust_0.11                                           0.938617
# spat_trust_0.12                                           0.940038
# spat_trust_0.13                                           0.941401
# spat_trust_0.14                                           0.942851
# spat_trust_0.15                                           0.944302
# spat_trust_0.16                                           0.945630
# spat_trust_0.17                                           0.946942
# spat_trust_0.18                                           0.948277
# spat_trust_0.19                                           0.949542
# spat_trust_0.2                                            0.950798
# spat_cont_0.01                                            0.845902
# spat_cont_0.02                                            0.854014
# spat_cont_0.03                                            0.861544
# spat_cont_0.04                                            0.868343
# spat_cont_0.05                                            0.874518
# spat_cont_0.06                                            0.880332
# spat_cont_0.07                                            0.885489
# spat_cont_0.08                                            0.889998
# spat_cont_0.09                                            0.894283
# spat_cont_0.1                                             0.898148
# spat_cont_0.11                                            0.901634
# spat_cont_0.12                                            0.904915
# spat_cont_0.13                                            0.907749
# spat_cont_0.14                                            0.910335
# spat_cont_0.15                                            0.912704
# spat_cont_0.16                                            0.914837
# spat_cont_0.17                                            0.916857
# spat_cont_0.18                                            0.918642
# spat_cont_0.19                                            0.920338
# spat_cont_0.2                                             0.921861
#
#                  output/walk-pcadtsne-p30-l0_000100-le1-ls10_00.csv  \
# stab_pearson                                             -0.587842
# stab_spearman                                            -0.473624
# stab_kendall                                             -0.286512
# stab_kl                                                   0.369187
# stab_stress_n                                             0.414862
# stab_stress_s                                             3.175684
# spat_pearson                                              0.974113
# spat_spearman                                             0.947554
# spat_kendall                                              0.813381
# spat_kl                                                   0.134725
# spat_stress_n                                             0.071107
# spat_stress_s                                             0.051774
# spat_np_0.01                                              0.215378
# spat_np_0.02                                              0.254500
# spat_np_0.03                                              0.288659
# spat_np_0.04                                              0.321000
# spat_np_0.05                                              0.351724
# spat_np_0.06                                              0.380537
# spat_np_0.07                                              0.408457
# spat_np_0.08                                              0.435425
# spat_np_0.09                                              0.461941
# spat_np_0.1                                               0.487091
# spat_np_0.11                                              0.510960
# spat_np_0.12                                              0.532989
# spat_np_0.13                                              0.553333
# spat_np_0.14                                              0.572749
# spat_np_0.15                                              0.591787
# spat_np_0.16                                              0.609682
# spat_np_0.17                                              0.627222
# spat_np_0.18                                              0.644286
# spat_np_0.19                                              0.660499
# spat_np_0.2                                               0.676482
# spat_nh_1                                                 0.916267
# spat_nh_2                                                 0.912567
# spat_nh_3                                                 0.910311
# spat_nh_4                                                 0.907517
# spat_nh_5                                                 0.905173
# spat_nh_6                                                 0.903678
# spat_nh_7                                                 0.901943
# spat_nh_8                                                 0.899992
# spat_nh_9                                                 0.898326
# spat_nh_10                                                0.896413
# spat_nh_11                                                0.894855
# spat_nh_12                                                0.893389
# spat_nh_13                                                0.891656
# spat_nh_14                                                0.890262
# spat_nh_15                                                0.888769
# spat_nh_16                                                0.887667
# spat_nh_17                                                0.886341
# spat_nh_18                                                0.885304
# spat_nh_19                                                0.884193
# spat_nh_20                                                0.883207
# spat_trust_0.01                                           0.932903
# spat_trust_0.02                                           0.926183
# spat_trust_0.03                                           0.924149
# spat_trust_0.04                                           0.923860
# spat_trust_0.05                                           0.924447
# spat_trust_0.06                                           0.925487
# spat_trust_0.07                                           0.926880
# spat_trust_0.08                                           0.928515
# spat_trust_0.09                                           0.930206
# spat_trust_0.1                                            0.932000
# spat_trust_0.11                                           0.933791
# spat_trust_0.12                                           0.935588
# spat_trust_0.13                                           0.937275
# spat_trust_0.14                                           0.939105
# spat_trust_0.15                                           0.940903
# spat_trust_0.16                                           0.942621
# spat_trust_0.17                                           0.944259
# spat_trust_0.18                                           0.945934
# spat_trust_0.19                                           0.947515
# spat_trust_0.2                                            0.949060
# spat_cont_0.01                                            0.865442
# spat_cont_0.02                                            0.865209
# spat_cont_0.03                                            0.867740
# spat_cont_0.04                                            0.871490
# spat_cont_0.05                                            0.875278
# spat_cont_0.06                                            0.879097
# spat_cont_0.07                                            0.882854
# spat_cont_0.08                                            0.886651
# spat_cont_0.09                                            0.890089
# spat_cont_0.1                                             0.893504
# spat_cont_0.11                                            0.896681
# spat_cont_0.12                                            0.899681
# spat_cont_0.13                                            0.902344
# spat_cont_0.14                                            0.904968
# spat_cont_0.15                                            0.907444
# spat_cont_0.16                                            0.909781
# spat_cont_0.17                                            0.911976
# spat_cont_0.18                                            0.914114
# spat_cont_0.19                                            0.916033
# spat_cont_0.2                                             0.917867
#
#                  output/walk-pcadtsne-p30-l0_001000-le1-ls0_10.csv  \
# stab_pearson                                              0.090023
# stab_spearman                                             0.119354
# stab_kendall                                              0.081422
# stab_kl                                                   0.522965
# stab_stress_n                                             0.779189
# stab_stress_s                                             1.819954
# spat_pearson                                              0.829702
# spat_spearman                                             0.878921
# spat_kendall                                              0.705811
# spat_kl                                                   0.129445
# spat_stress_n                                             0.308509
# spat_stress_s                                             0.340597
# spat_np_0.01                                              0.088822
# spat_np_0.02                                              0.142378
# spat_np_0.03                                              0.190407
# spat_np_0.04                                              0.232983
# spat_np_0.05                                              0.271907
# spat_np_0.06                                              0.309200
# spat_np_0.07                                              0.343673
# spat_np_0.08                                              0.376511
# spat_np_0.09                                              0.408198
# spat_np_0.1                                               0.437298
# spat_np_0.11                                              0.464671
# spat_np_0.12                                              0.490150
# spat_np_0.13                                              0.514036
# spat_np_0.14                                              0.536910
# spat_np_0.15                                              0.559079
# spat_np_0.16                                              0.579524
# spat_np_0.17                                              0.599225
# spat_np_0.18                                              0.618333
# spat_np_0.19                                              0.636498
# spat_np_0.2                                               0.653649
# spat_nh_1                                                 0.905000
# spat_nh_2                                                 0.902067
# spat_nh_3                                                 0.899333
# spat_nh_4                                                 0.896683
# spat_nh_5                                                 0.893507
# spat_nh_6                                                 0.890200
# spat_nh_7                                                 0.886981
# spat_nh_8                                                 0.884817
# spat_nh_9                                                 0.882548
# spat_nh_10                                                0.879940
# spat_nh_11                                                0.877733
# spat_nh_12                                                0.875322
# spat_nh_13                                                0.873272
# spat_nh_14                                                0.871105
# spat_nh_15                                                0.869347
# spat_nh_16                                                0.867500
# spat_nh_17                                                0.865506
# spat_nh_18                                                0.863819
# spat_nh_19                                                0.862211
# spat_nh_20                                                0.860773
# spat_trust_0.01                                           0.914625
# spat_trust_0.02                                           0.911547
# spat_trust_0.03                                           0.911464
# spat_trust_0.04                                           0.912685
# spat_trust_0.05                                           0.914560
# spat_trust_0.06                                           0.916701
# spat_trust_0.07                                           0.918926
# spat_trust_0.08                                           0.921249
# spat_trust_0.09                                           0.923560
# spat_trust_0.1                                            0.925938
# spat_trust_0.11                                           0.928235
# spat_trust_0.12                                           0.930454
# spat_trust_0.13                                           0.932551
# spat_trust_0.14                                           0.934687
# spat_trust_0.15                                           0.936788
# spat_trust_0.16                                           0.938724
# spat_trust_0.17                                           0.940594
# spat_trust_0.18                                           0.942424
# spat_trust_0.19                                           0.944102
# spat_trust_0.2                                            0.945620
# spat_cont_0.01                                            0.830769
# spat_cont_0.02                                            0.836482
# spat_cont_0.03                                            0.842482
# spat_cont_0.04                                            0.848752
# spat_cont_0.05                                            0.853821
# spat_cont_0.06                                            0.859333
# spat_cont_0.07                                            0.864289
# spat_cont_0.08                                            0.869149
# spat_cont_0.09                                            0.873796
# spat_cont_0.1                                             0.878130
# spat_cont_0.11                                            0.882195
# spat_cont_0.12                                            0.885889
# spat_cont_0.13                                            0.889483
# spat_cont_0.14                                            0.892793
# spat_cont_0.15                                            0.895887
# spat_cont_0.16                                            0.898794
# spat_cont_0.17                                            0.901521
# spat_cont_0.18                                            0.904120
# spat_cont_0.19                                            0.906408
# spat_cont_0.2                                             0.908357
#
#                  output/walk-pcadtsne-p30-l0_001000-le1-ls1_00.csv  \
# stab_pearson                                             -0.334608
# stab_spearman                                            -0.333309
# stab_kendall                                             -0.192428
# stab_kl                                                   0.290493
# stab_stress_n                                             0.560268
# stab_stress_s                                             2.669216
# spat_pearson                                              0.972527
# spat_spearman                                             0.940075
# spat_kendall                                              0.802000
# spat_kl                                                   0.088272
# spat_stress_n                                             0.059537
# spat_stress_s                                             0.054945
# spat_np_0.01                                              0.109333
# spat_np_0.02                                              0.175378
# spat_np_0.03                                              0.230363
# spat_np_0.04                                              0.277572
# spat_np_0.05                                              0.319142
# spat_np_0.06                                              0.356978
# spat_np_0.07                                              0.391857
# spat_np_0.08                                              0.424644
# spat_np_0.09                                              0.455252
# spat_np_0.1                                               0.483620
# spat_np_0.11                                              0.510141
# spat_np_0.12                                              0.534694
# spat_np_0.13                                              0.557426
# spat_np_0.14                                              0.578800
# spat_np_0.15                                              0.598713
# spat_np_0.16                                              0.617485
# spat_np_0.17                                              0.635591
# spat_np_0.18                                              0.652681
# spat_np_0.19                                              0.669145
# spat_np_0.2                                               0.685311
# spat_nh_1                                                 0.909733
# spat_nh_2                                                 0.907233
# spat_nh_3                                                 0.904778
# spat_nh_4                                                 0.902917
# spat_nh_5                                                 0.900867
# spat_nh_6                                                 0.899189
# spat_nh_7                                                 0.897629
# spat_nh_8                                                 0.896192
# spat_nh_9                                                 0.894370
# spat_nh_10                                                0.892473
# spat_nh_11                                                0.890970
# spat_nh_12                                                0.889456
# spat_nh_13                                                0.888000
# spat_nh_14                                                0.886457
# spat_nh_15                                                0.885231
# spat_nh_16                                                0.884117
# spat_nh_17                                                0.882922
# spat_nh_18                                                0.881456
# spat_nh_19                                                0.880281
# spat_nh_20                                                0.879150
# spat_trust_0.01                                           0.929972
# spat_trust_0.02                                           0.926264
# spat_trust_0.03                                           0.925765
# spat_trust_0.04                                           0.926468
# spat_trust_0.05                                           0.927674
# spat_trust_0.06                                           0.929193
# spat_trust_0.07                                           0.930877
# spat_trust_0.08                                           0.932708
# spat_trust_0.09                                           0.934524
# spat_trust_0.1                                            0.936412
# spat_trust_0.11                                           0.938241
# spat_trust_0.12                                           0.939996
# spat_trust_0.13                                           0.941629
# spat_trust_0.14                                           0.943351
# spat_trust_0.15                                           0.945049
# spat_trust_0.16                                           0.946606
# spat_trust_0.17                                           0.948123
# spat_trust_0.18                                           0.949631
# spat_trust_0.19                                           0.951057
# spat_trust_0.2                                            0.952468
# spat_cont_0.01                                            0.840741
# spat_cont_0.02                                            0.849309
# spat_cont_0.03                                            0.856930
# spat_cont_0.04                                            0.863693
# spat_cont_0.05                                            0.869974
# spat_cont_0.06                                            0.875688
# spat_cont_0.07                                            0.881037
# spat_cont_0.08                                            0.885942
# spat_cont_0.09                                            0.890525
# spat_cont_0.1                                             0.894689
# spat_cont_0.11                                            0.898504
# spat_cont_0.12                                            0.902101
# spat_cont_0.13                                            0.905392
# spat_cont_0.14                                            0.908279
# spat_cont_0.15                                            0.911034
# spat_cont_0.16                                            0.913524
# spat_cont_0.17                                            0.915838
# spat_cont_0.18                                            0.918009
# spat_cont_0.19                                            0.919991
# spat_cont_0.2                                             0.921850
#
#                  output/walk-pcadtsne-p30-l0_001000-le1-ls10_00.csv  \
# stab_pearson                                             -0.650334
# stab_spearman                                            -0.380410
# stab_kendall                                             -0.169982
# stab_kl                                                   0.354855
# stab_stress_n                                             0.314203
# stab_stress_s                                             3.300669
# spat_pearson                                              0.980060
# spat_spearman                                             0.959805
# spat_kendall                                              0.845486
# spat_kl                                                   0.132989
# spat_stress_n                                             0.068923
# spat_stress_s                                             0.039880
# spat_np_0.01                                              0.118667
# spat_np_0.02                                              0.179033
# spat_np_0.03                                              0.228052
# spat_np_0.04                                              0.270794
# spat_np_0.05                                              0.308253
# spat_np_0.06                                              0.343056
# spat_np_0.07                                              0.375473
# spat_np_0.08                                              0.406406
# spat_np_0.09                                              0.435047
# spat_np_0.1                                               0.462020
# spat_np_0.11                                              0.487251
# spat_np_0.12                                              0.511552
# spat_np_0.13                                              0.534232
# spat_np_0.14                                              0.555851
# spat_np_0.15                                              0.576684
# spat_np_0.16                                              0.596474
# spat_np_0.17                                              0.615275
# spat_np_0.18                                              0.633811
# spat_np_0.19                                              0.651254
# spat_np_0.2                                               0.668298
# spat_nh_1                                                 0.907933
# spat_nh_2                                                 0.906267
# spat_nh_3                                                 0.903822
# spat_nh_4                                                 0.902267
# spat_nh_5                                                 0.901213
# spat_nh_6                                                 0.899733
# spat_nh_7                                                 0.898724
# spat_nh_8                                                 0.897458
# spat_nh_9                                                 0.896474
# spat_nh_10                                                0.895213
# spat_nh_11                                                0.894079
# spat_nh_12                                                0.892978
# spat_nh_13                                                0.892108
# spat_nh_14                                                0.891181
# spat_nh_15                                                0.890187
# spat_nh_16                                                0.889208
# spat_nh_17                                                0.888220
# spat_nh_18                                                0.887407
# spat_nh_19                                                0.886730
# spat_nh_20                                                0.886000
# spat_trust_0.01                                           0.918118
# spat_trust_0.02                                           0.915158
# spat_trust_0.03                                           0.915157
# spat_trust_0.04                                           0.916228
# spat_trust_0.05                                           0.917833
# spat_trust_0.06                                           0.919779
# spat_trust_0.07                                           0.921860
# spat_trust_0.08                                           0.924087
# spat_trust_0.09                                           0.926304
# spat_trust_0.1                                            0.928609
# spat_trust_0.11                                           0.930849
# spat_trust_0.12                                           0.933073
# spat_trust_0.13                                           0.935129
# spat_trust_0.14                                           0.937302
# spat_trust_0.15                                           0.939411
# spat_trust_0.16                                           0.941403
# spat_trust_0.17                                           0.943337
# spat_trust_0.18                                           0.945239
# spat_trust_0.19                                           0.947041
# spat_trust_0.2                                            0.948813
# spat_cont_0.01                                            0.842650
# spat_cont_0.02                                            0.847926
# spat_cont_0.03                                            0.854234
# spat_cont_0.04                                            0.859663
# spat_cont_0.05                                            0.864493
# spat_cont_0.06                                            0.869191
# spat_cont_0.07                                            0.873471
# spat_cont_0.08                                            0.877734
# spat_cont_0.09                                            0.881621
# spat_cont_0.1                                             0.885349
# spat_cont_0.11                                            0.888850
# spat_cont_0.12                                            0.892354
# spat_cont_0.13                                            0.895535
# spat_cont_0.14                                            0.898549
# spat_cont_0.15                                            0.901332
# spat_cont_0.16                                            0.904069
# spat_cont_0.17                                            0.906649
# spat_cont_0.18                                            0.909125
# spat_cont_0.19                                            0.911305
# spat_cont_0.2                                             0.913445
#
#                  output/walk-pcadtsne-p30-l0_010000-le1-ls0_10.csv  \
# stab_pearson                                             -0.623965
# stab_spearman                                            -0.438594
# stab_kendall                                             -0.238131
# stab_kl                                                   0.328482
# stab_stress_n                                             0.313659
# stab_stress_s                                             3.247931
# spat_pearson                                              0.977100
# spat_spearman                                             0.962999
# spat_kendall                                              0.850897
# spat_kl                                                   0.135976
# spat_stress_n                                             0.057392
# spat_stress_s                                             0.045800
# spat_np_0.01                                              0.085000
# spat_np_0.02                                              0.149211
# spat_np_0.03                                              0.201978
# spat_np_0.04                                              0.247733
# spat_np_0.05                                              0.287827
# spat_np_0.06                                              0.325333
# spat_np_0.07                                              0.359683
# spat_np_0.08                                              0.391847
# spat_np_0.09                                              0.422886
# spat_np_0.1                                               0.451282
# spat_np_0.11                                              0.477877
# spat_np_0.12                                              0.503494
# spat_np_0.13                                              0.526991
# spat_np_0.14                                              0.549637
# spat_np_0.15                                              0.571899
# spat_np_0.16                                              0.592256
# spat_np_0.17                                              0.611629
# spat_np_0.18                                              0.630784
# spat_np_0.19                                              0.649323
# spat_np_0.2                                               0.666764
# spat_nh_1                                                 0.895067
# spat_nh_2                                                 0.893267
# spat_nh_3                                                 0.893600
# spat_nh_4                                                 0.892217
# spat_nh_5                                                 0.891253
# spat_nh_6                                                 0.889322
# spat_nh_7                                                 0.888048
# spat_nh_8                                                 0.886892
# spat_nh_9                                                 0.885667
# spat_nh_10                                                0.884413
# spat_nh_11                                                0.883182
# spat_nh_12                                                0.882522
# spat_nh_13                                                0.881513
# spat_nh_14                                                0.880533
# spat_nh_15                                                0.879862
# spat_nh_16                                                0.879029
# spat_nh_17                                                0.878388
# spat_nh_18                                                0.877685
# spat_nh_19                                                0.876937
# spat_nh_20                                                0.876283
# spat_trust_0.01                                           0.913640
# spat_trust_0.02                                           0.912258
# spat_trust_0.03                                           0.913074
# spat_trust_0.04                                           0.914744
# spat_trust_0.05                                           0.916797
# spat_trust_0.06                                           0.919078
# spat_trust_0.07                                           0.921419
# spat_trust_0.08                                           0.923859
# spat_trust_0.09                                           0.926254
# spat_trust_0.1                                            0.928700
# spat_trust_0.11                                           0.931061
# spat_trust_0.12                                           0.933387
# spat_trust_0.13                                           0.935548
# spat_trust_0.14                                           0.937803
# spat_trust_0.15                                           0.939993
# spat_trust_0.16                                           0.942034
# spat_trust_0.17                                           0.944015
# spat_trust_0.18                                           0.945968
# spat_trust_0.19                                           0.947802
# spat_trust_0.2                                            0.949607
# spat_cont_0.01                                            0.834174
# spat_cont_0.02                                            0.841419
# spat_cont_0.03                                            0.848773
# spat_cont_0.04                                            0.855346
# spat_cont_0.05                                            0.860980
# spat_cont_0.06                                            0.866306
# spat_cont_0.07                                            0.871209
# spat_cont_0.08                                            0.875766
# spat_cont_0.09                                            0.880213
# spat_cont_0.1                                             0.884189
# spat_cont_0.11                                            0.887921
# spat_cont_0.12                                            0.891664
# spat_cont_0.13                                            0.895043
# spat_cont_0.14                                            0.898239
# spat_cont_0.15                                            0.901310
# spat_cont_0.16                                            0.904271
# spat_cont_0.17                                            0.906931
# spat_cont_0.18                                            0.909565
# spat_cont_0.19                                            0.912077
# spat_cont_0.2                                             0.914348
#
#                  output/walk-pcadtsne-p30-l0_010000-le1-ls1_00.csv  \
# stab_pearson                                             -0.641467
# stab_spearman                                            -0.367800
# stab_kendall                                             -0.151885
# stab_kl                                                   0.339142
# stab_stress_n                                             0.306547
# stab_stress_s                                             3.282935
# spat_pearson                                              0.980498
# spat_spearman                                             0.959887
# spat_kendall                                              0.846894
# spat_kl                                                   0.127653
# spat_stress_n                                             0.064595
# spat_stress_s                                             0.039005
# spat_np_0.01                                              0.084133
# spat_np_0.02                                              0.148778
# spat_np_0.03                                              0.200763
# spat_np_0.04                                              0.246883
# spat_np_0.05                                              0.287151
# spat_np_0.06                                              0.324148
# spat_np_0.07                                              0.358594
# spat_np_0.08                                              0.390922
# spat_np_0.09                                              0.421763
# spat_np_0.1                                               0.449987
# spat_np_0.11                                              0.476743
# spat_np_0.12                                              0.502350
# spat_np_0.13                                              0.525851
# spat_np_0.14                                              0.548333
# spat_np_0.15                                              0.570569
# spat_np_0.16                                              0.591147
# spat_np_0.17                                              0.610684
# spat_np_0.18                                              0.629746
# spat_np_0.19                                              0.648083
# spat_np_0.2                                               0.665683
# spat_nh_1                                                 0.898133
# spat_nh_2                                                 0.896167
# spat_nh_3                                                 0.896133
# spat_nh_4                                                 0.895333
# spat_nh_5                                                 0.894187
# spat_nh_6                                                 0.893089
# spat_nh_7                                                 0.892457
# spat_nh_8                                                 0.891375
# spat_nh_9                                                 0.890407
# spat_nh_10                                                0.889067
# spat_nh_11                                                0.887770
# spat_nh_12                                                0.886972
# spat_nh_13                                                0.886226
# spat_nh_14                                                0.885576
# spat_nh_15                                                0.884636
# spat_nh_16                                                0.883904
# spat_nh_17                                                0.883094
# spat_nh_18                                                0.882367
# spat_nh_19                                                0.881639
# spat_nh_20                                                0.881027
# spat_trust_0.01                                           0.912512
# spat_trust_0.02                                           0.911234
# spat_trust_0.03                                           0.912101
# spat_trust_0.04                                           0.913803
# spat_trust_0.05                                           0.915888
# spat_trust_0.06                                           0.918216
# spat_trust_0.07                                           0.920596
# spat_trust_0.08                                           0.923072
# spat_trust_0.09                                           0.925504
# spat_trust_0.1                                            0.927986
# spat_trust_0.11                                           0.930374
# spat_trust_0.12                                           0.932725
# spat_trust_0.13                                           0.934902
# spat_trust_0.14                                           0.937185
# spat_trust_0.15                                           0.939390
# spat_trust_0.16                                           0.941446
# spat_trust_0.17                                           0.943438
# spat_trust_0.18                                           0.945389
# spat_trust_0.19                                           0.947233
# spat_trust_0.2                                            0.949043
# spat_cont_0.01                                            0.833322
# spat_cont_0.02                                            0.840835
# spat_cont_0.03                                            0.848035
# spat_cont_0.04                                            0.854339
# spat_cont_0.05                                            0.859911
# spat_cont_0.06                                            0.865173
# spat_cont_0.07                                            0.870123
# spat_cont_0.08                                            0.874802
# spat_cont_0.09                                            0.879120
# spat_cont_0.1                                             0.883180
# spat_cont_0.11                                            0.887040
# spat_cont_0.12                                            0.890705
# spat_cont_0.13                                            0.894152
# spat_cont_0.14                                            0.897349
# spat_cont_0.15                                            0.900490
# spat_cont_0.16                                            0.903411
# spat_cont_0.17                                            0.906131
# spat_cont_0.18                                            0.908746
# spat_cont_0.19                                            0.911189
# spat_cont_0.2                                             0.913482
#
#                  output/walk-pcadtsne-p30-l0_010000-le1-ls10_00.csv
# stab_pearson                                             -0.664368
# stab_spearman                                            -0.340343
# stab_kendall                                             -0.114467
# stab_kl                                                   0.351601
# stab_stress_n                                             0.327986
# stab_stress_s                                             3.328736
# spat_pearson                                              0.980352
# spat_spearman                                             0.960921
# spat_kendall                                              0.848812
# spat_kl                                                   0.135780
# spat_stress_n                                             0.067774
# spat_stress_s                                             0.039296
# spat_np_0.01                                              0.083578
# spat_np_0.02                                              0.145967
# spat_np_0.03                                              0.196756
# spat_np_0.04                                              0.241828
# spat_np_0.05                                              0.281329
# spat_np_0.06                                              0.318400
# spat_np_0.07                                              0.352578
# spat_np_0.08                                              0.384514
# spat_np_0.09                                              0.414536
# spat_np_0.1                                               0.442636
# spat_np_0.11                                              0.469600
# spat_np_0.12                                              0.494948
# spat_np_0.13                                              0.518667
# spat_np_0.14                                              0.541665
# spat_np_0.15                                              0.564068
# spat_np_0.16                                              0.584892
# spat_np_0.17                                              0.604901
# spat_np_0.18                                              0.624302
# spat_np_0.19                                              0.642695
# spat_np_0.2                                               0.660427
# spat_nh_1                                                 0.898667
# spat_nh_2                                                 0.899200
# spat_nh_3                                                 0.897622
# spat_nh_4                                                 0.897183
# spat_nh_5                                                 0.896987
# spat_nh_6                                                 0.895789
# spat_nh_7                                                 0.894990
# spat_nh_8                                                 0.893800
# spat_nh_9                                                 0.892756
# spat_nh_10                                                0.891893
# spat_nh_11                                                0.890800
# spat_nh_12                                                0.890094
# spat_nh_13                                                0.889256
# spat_nh_14                                                0.888519
# spat_nh_15                                                0.887649
# spat_nh_16                                                0.886837
# spat_nh_17                                                0.886224
# spat_nh_18                                                0.885596
# spat_nh_19                                                0.884961
# spat_nh_20                                                0.884577
# spat_trust_0.01                                           0.906145
# spat_trust_0.02                                           0.905840
# spat_trust_0.03                                           0.907212
# spat_trust_0.04                                           0.909260
# spat_trust_0.05                                           0.911679
# spat_trust_0.06                                           0.914283
# spat_trust_0.07                                           0.916893
# spat_trust_0.08                                           0.919580
# spat_trust_0.09                                           0.922220
# spat_trust_0.1                                            0.924898
# spat_trust_0.11                                           0.927462
# spat_trust_0.12                                           0.929989
# spat_trust_0.13                                           0.932336
# spat_trust_0.14                                           0.934779
# spat_trust_0.15                                           0.937125
# spat_trust_0.16                                           0.939321
# spat_trust_0.17                                           0.941449
# spat_trust_0.18                                           0.943519
# spat_trust_0.19                                           0.945481
# spat_trust_0.2                                            0.947402
# spat_cont_0.01                                            0.832551
# spat_cont_0.02                                            0.840090
# spat_cont_0.03                                            0.846791
# spat_cont_0.04                                            0.852443
# spat_cont_0.05                                            0.857772
# spat_cont_0.06                                            0.862926
# spat_cont_0.07                                            0.867841
# spat_cont_0.08                                            0.872451
# spat_cont_0.09                                            0.876688
# spat_cont_0.1                                             0.880675
# spat_cont_0.11                                            0.884471
# spat_cont_0.12                                            0.888158
# spat_cont_0.13                                            0.891541
# spat_cont_0.14                                            0.894819
# spat_cont_0.15                                            0.897908
# spat_cont_0.16                                            0.900862
# spat_cont_0.17                                            0.903630
# spat_cont_0.18                                            0.906304
# spat_cont_0.19                                            0.908693
# spat_cont_0.2                                             0.911010

# %%
metric_results.to_csv('./metrics/results/{}_.csv'.format(dataset_id))
