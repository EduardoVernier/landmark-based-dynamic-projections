# %%
# !which python
# Out:
# /home/eduardo/.local/share/virtualenvs/landmark-based-dynamic-projections-fPQXII6E/bin/python

# %%
# !which jupyter-notebook
# Out:
# /home/eduardo/.local/bin/jupyter-notebook

# %%
from natsort import natsorted
import glob 
# projection_paths = natsorted(glob.glob('../tests/static-tests/fashion-*'))

# %%
# This is the parameters cell
projection_paths = [
'output/quickdraw-pcadtsne-p30-l0_000100-le1-ls0_10.csv',
'output/quickdraw-pcadtsne-p30-l0_000100-le1-ls1_00.csv',
'output/quickdraw-pcadtsne-p30-l0_000100-le1-ls10_00.csv',
'output/quickdraw-pcadtsne-p30-l0_001000-le1-ls0_10.csv',
'output/quickdraw-pcadtsne-p30-l0_001000-le1-ls1_00.csv',
'output/quickdraw-pcadtsne-p30-l0_001000-le1-ls10_00.csv',
'output/quickdraw-pcadtsne-p30-l0_010000-le1-ls0_10.csv',
'output/quickdraw-pcadtsne-p30-l0_010000-le1-ls1_00.csv',
'output/quickdraw-pcadtsne-p30-l0_010000-le1-ls10_00.csv'
]

# %%
# projection_paths = projection_paths.split(' ')
dataset_id = projection_paths[0].split('/')[-1].split('-')[0]
print(projection_paths, dataset_id)
# Out:
# ['output/qtables-pcadtsne-p30-l0_000010-le1-ls0_10.csv', 'output/qtables-pcadtsne-p30-l0_000010-le1-ls1_00.csv', 'output/qtables-pcadtsne-p30-l0_000010-le1-ls10_00.csv', 'output/qtables-pcadtsne-p30-l0_000100-le1-ls0_10.csv', 'output/qtables-pcadtsne-p30-l0_000100-le1-ls1_00.csv', 'output/qtables-pcadtsne-p30-l0_000100-le1-ls10_00.csv', 'output/qtables-pcadtsne-p30-l0_001000-le1-ls0_10.csv', 'output/qtables-pcadtsne-p30-l0_001000-le1-ls1_00.csv', 'output/qtables-pcadtsne-p30-l0_001000-le1-ls10_00.csv', 'output/qtables-pcadtsne-p30-l0_010000-le1-ls0_10.csv', 'output/qtables-pcadtsne-p30-l0_010000-le1-ls1_00.csv', 'output/qtables-pcadtsne-p30-l0_010000-le1-ls10_00.csv'] qtables

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats
import math
import cv2
import re
import glob
import sys
from sklearn.neighbors import NearestNeighbors
import os
# Uncomment next line if testing
os.chdir('..')

IMAGE_DATASETS = ['quickdraw', 'fashion']
K_VALUES = [i/100 for i in range(1,21)]

# %%
# log = 'Metrics/log_' + dataset_id
# sys.stderr = open('Metrics/log_' + dataset_id, 'w') # to check tqdm progress followed by watch -n 1 cat logfile

# %% [markdown]
# # Stability metrics

# %%
def get_projection_as_array(dataset_path):
    df = pd.read_csv(dataset_path, index_col=0)
    vs = df.values.reshape(len(df), -1, 2)
    return vs, list(df.index), vs.shape[1]


def get_md_mov(dataset_path):
    vs, indexes, n_timesteps = get_projection_as_array(dataset_path)
    mov = []
    for poly in vs:
        mov_i = []
        for i in range(len(poly)-1):
            mov_i.append(math.sqrt(np.sum(np.square(poly[i] - poly[i+1]))))
        mov.append(np.array(mov_i))
    return np.array(mov), indexes, n_timesteps


# get_md_mov('./Output/quickdraw-pca_s4.csv')

# %%
def image_dataset_to_array(dataset_path):
    # Convert image to np array
    # Preload images to memory (trying to speed things up)
    all_files = glob.glob('{}*'.format(dataset_path))
    # Gather ids and timestep info    
    max_t = {}
    for f in all_files:
        regex = r".*/{}/(.*-.*)-(.*).png".format(dataset_id)
        match = re.match(regex, f)
        img_id, t = match.groups()
        t = int(t)
        max_t[img_id] = max_t[img_id] if img_id in max_t and max_t[img_id] > t else t   
    
    img_size = 28 * 28  # Pixel count
    n_revisions = max(max_t.values()) + 1
    n_items = len(max_t.values())
    vs = np.empty((n_revisions, n_items, img_size))
    
    # Populate vs
    for i, img_id in enumerate(natsorted(max_t)):
        # Copy existing bitmaps to np.array
        for t in range(0, max_t[img_id]):
            img_file = dataset_path + img_id + '-' + str(t) + '.png'
            vs[t][i] = (cv2.imread(img_file, cv2.IMREAD_GRAYSCALE) / 255.).flatten()
        # Replicate last image
        for t in range(max_t[img_id], n_revisions):
            img_file = dataset_path + img_id + '-' + str(max_t[img_id]-1) + '.png'
            vs[t][i] = (cv2.imread(img_file, cv2.IMREAD_GRAYSCALE) / 255.).flatten()    
    return vs, list(natsorted(max_t)), n_revisions


def tabular_dataset_to_array(dataset_path):
    # Get files with coords and save in an array vs
    all_files = natsorted(glob.glob('{}*'.format(dataset_path)))
    vs = [pd.read_csv(f, index_col=0).values for f in all_files] 
    # Get dataset info 
    df_temp = pd.read_csv(all_files[0], index_col=0)
    n_timesteps = len(all_files)
    return np.array(vs), list(df_temp.index), n_timesteps


def dataset_as_array(dataset_path):
    if dataset_id in IMAGE_DATASETS:
         return image_dataset_to_array(dataset_path)
    else:
        return tabular_dataset_to_array(dataset_path)


def get_nd_mov(dataset_id):
    mov = []
    dataset_path = './datasets/' + dataset_id + '/'
    # Get the nd data into arrays
    vs, indexes, n_timesteps = dataset_as_array(dataset_path)
    # Compute dists between 2 nd arrays
    for t in range(n_timesteps - 1):
        v_t = vs[t]
        v_tp1 = vs[t+1]
        mov_t = []
        for a, b in zip(v_t, v_tp1):
            mov_t.append(math.sqrt(np.sum(np.square(a - b))))
        mov.append(np.array(mov_t)) 
    return np.array(mov).T, indexes, n_timesteps

# dists, indexes, n_timesteps = get_nd_dists('quickdraw')

# %%
# Compute distances
mov_nd, indexes, n_timesteps = get_nd_mov(dataset_id)
mov_md_dict = {}
for p in projection_paths:
    mov, _, _ = get_md_mov(p)
    mov_md_dict[p] = mov

# %%
metric_ids = ['stab_pearson', 'stab_spearman', 'stab_kendall', 'stab_kl', 'stab_stress_n', 'stab_stress_s',
              'spat_pearson', 'spat_spearman', 'spat_kendall', 'spat_kl', 'spat_stress_n', 'spat_stress_s']

for i in K_VALUES:
    metric_ids.append('spat_np_' + str(i))
for i in range(1,21):
    metric_ids.append('spat_nh_' + str(i))
for i in K_VALUES:
    metric_ids.append('spat_trust_' + str(i))
for i in K_VALUES:
    metric_ids.append('spat_cont_' + str(i))

metric_results = pd.DataFrame(np.zeros((len(projection_paths), len(metric_ids))),
                              index=projection_paths, columns=metric_ids)
# metric_results

# %% [markdown]
# # Stability metrics

# %%
# Flatten the data
mov_nd = mov_nd.flatten()
for p in projection_paths:
    mov_md = mov_md_dict[p].flatten()

    # Correlation and divergence metrics
    metric_results.loc[p]['stab_pearson']  = scipy.stats.pearsonr(mov_nd, mov_md)[0]
    metric_results.loc[p]['stab_spearman'] = scipy.stats.spearmanr(mov_nd, mov_md)[0]
    metric_results.loc[p]['stab_kendall']  = scipy.stats.kendalltau(mov_nd, mov_md)[0]
    metric_results.loc[p]['stab_kl']       = scipy.stats.entropy(mov_nd, mov_md)

    # Stress metrics
    nd = mov_nd / max(mov_nd)
    md = mov_md / max(mov_md)
    metric_results.loc[p]['stab_stress_n'] = np.sum(np.square(nd - md)) / np.sum(np.square(nd))

    nd = (mov_nd - np.mean(mov_nd)) / np.std(mov_nd)
    md = (mov_md - np.mean(mov_md)) / np.std(mov_md)
    metric_results.loc[p]['stab_stress_s'] = np.sum(np.square(nd - md)) / np.sum(np.square(nd))

# display(metric_results)

# %% [markdown]
# # Spatial metrics

# %%
def trustworthiness_metric(nbrs_nd, nbrs_md, k):
    sum_i = 0
    for i in range(n_items):
        # Look for false neighbors in a k sized neighborhood
        knbrs_nd = nbrs_nd[i, 1:k+1]
        knbrs_md = nbrs_md[i, 1:k+1]
        U = np.setdiff1d(knbrs_nd, knbrs_md, assume_unique=True)

        # For each false neighbor in mD, find out its rank in nD and sum it
        sum_j = 0
        for j in U: 
            sum_j += int(np.where(nbrs_md[i] == j)[0] - 1) - k   
        sum_i += int(sum_j)

    n = n_items
    return float((1 - (2 / (n * k * (2 * n - 3 * k - 1)) * sum_i)))

def continuity_metric(nbrs_nd, nbrs_md, k):
    sum_i = 0
    for i in range(n_items):
        # Look for false neighbors in a k sized neighborhood
        knbrs_nd = nbrs_nd[i, 1:k+1]
        knbrs_md = nbrs_md[i, 1:k+1]
        U = np.setdiff1d(knbrs_md, knbrs_nd, assume_unique=True)

        # For each false neighbor in nD, find out its rank in mD and sum it
        sum_j = 0
        for j in U: 
            sum_j += int(np.where(nbrs_nd[i] == j)[0] - 1) - k   
        sum_i += int(sum_j)

    n = n_items
    return float((1 - (2 / (n * k * (2 * n - 3 * k - 1)) * sum_i)))

# %%
# %%time

dataset_path = './datasets/' + dataset_id + '/'
vs_n, indexes, n_revisions = dataset_as_array(dataset_path)
n_items = len(indexes)

for p in projection_paths:
    # Change axis in projection
    vs_m, _, _ = get_projection_as_array(p)
    vs_m = np.transpose(vs_m, (1,0,2))
    
    # Initialize structures
    index_to_class = np.array([item.split('-')[0] for item in np.array(indexes)])
    dists_nd_all = []
    dists_md_all = [] 
    ngbr_preservation = np.zeros((n_timesteps, n_items, len(K_VALUES)))
    ngbr_hit = np.zeros((n_timesteps, n_items, len(K_VALUES)))
    trustworthiness = np.zeros((n_timesteps, len(K_VALUES)))
    continuity = np.zeros((n_timesteps, len(K_VALUES)))
    
    for t in range(n_timesteps):
        # Generate list of nearest neighbors for each item in timestep t
        dists_nd, nbrs_nd = NearestNeighbors(n_neighbors=n_items, metric='euclidean',
                                      algorithm='ball_tree').fit(vs_n[t]).kneighbors(vs_n[t])   
        dists_md, nbrs_md = NearestNeighbors(n_neighbors=n_items, metric='euclidean',
                                      algorithm='kd_tree').fit(vs_m[t]).kneighbors(vs_m[t])
        
        # Save distances to compute correlation/stress metrics
        dists_nd_all.append(dists_nd)
        dists_md_all.append(dists_md)
        
        # Check classes of neighbors for neighbor hit metric
        for i in range(n_items):
            i_class = index_to_class[i]
            k_max = int(max(K_VALUES) * n_items)
            ngbr_classes = index_to_class[nbrs_md[i, 1:k_max]]
            #for k_index, k_percentage in enumerate(np.divide(K_VALUES, 4)):
            #    k = max(int(k_percentage * n_items), 1)  # Avoid divisions by 0
            for k in range(1,21):
                ngbr_classes_of_i_over_k = ngbr_classes[:k]
                nh = sum(map(lambda x: x == i_class, ngbr_classes_of_i_over_k)) / float(k)
                ngbr_hit[t][i][k-1] = nh  

        # Compute neighbor preservation for different values of k for each item 
        for i in range(n_items):
            for k_index, k_percentage in enumerate(K_VALUES):
                k = max(int(k_percentage * n_items), 1)  # Avoid divisions by 0
                intersection = np.intersect1d(nbrs_nd[i, 1:k+1], nbrs_md[i, 1:k+1], assume_unique=True)
                ngbr_preservation[t][i][k_index] = len(intersection) / float(k)
                
        # Compute trustworthiness
        for k_index, k_percentage in enumerate(K_VALUES):
            k = max(int(k_percentage * n_items), 1)  # Avoid divisions by 0
            trustworthiness[t][k_index] = trustworthiness_metric(nbrs_nd, nbrs_md, k)
            continuity[t][k_index] = continuity_metric(nbrs_nd, nbrs_md, k)
        
        
    # Average values over TIME (axis 0)
    ngbr_preservation = np.average(ngbr_preservation, axis=0)
    ngbr_hit = np.average(ngbr_hit, axis=0)
    trustworthiness = np.average(trustworthiness, axis=0)
    continuity = np.average(continuity, axis=0)

    # Then average values over all points (new axis 0)
    ngbr_preservation = np.average(ngbr_preservation, axis=0)
    ngbr_hit = np.average(ngbr_hit, axis=0)

    # We get one value per k
    for i, k in enumerate(K_VALUES):
        metric_results.loc[p]['spat_np_' + str(k)]    = ngbr_preservation[i]
        metric_results.loc[p]['spat_trust_' + str(k)] = trustworthiness[i]
        metric_results.loc[p]['spat_cont_' + str(k)]  = continuity[i]
    for i, k in enumerate(range(1,21)):
        metric_results.loc[p]['spat_nh_' + str(k)]  = ngbr_hit[i]
        
    
    dists_nd_all = np.array(dists_nd_all)
    dists_md_all = np.array(dists_md_all)
    dists_nd_all = dists_nd_all.flatten()
    dists_md_all = dists_md_all.flatten()

    # Stress metrics
    nd = dists_nd_all / max(dists_nd_all)
    md = dists_md_all / max(dists_md_all)
    metric_results.loc[p]['spat_stress_n'] = np.sum(np.square(nd - md)) / np.sum(np.square(nd))

    nd = (dists_nd_all - np.mean(dists_nd_all)) / np.std(dists_nd_all)
    md = (dists_md_all - np.mean(dists_md_all)) / np.std(dists_md_all)
    metric_results.loc[p]['spat_stress_s'] = np.sum(np.square(nd - md)) / np.sum(np.square(nd))
    
    # Correlation and divergence metrics
    metric_results.loc[p]['spat_pearson']  = scipy.stats.pearsonr(dists_nd_all, dists_md_all)[0]
    metric_results.loc[p]['spat_spearman'] = scipy.stats.spearmanr(dists_nd_all, dists_md_all)[0]
    metric_results.loc[p]['spat_kendall']  = scipy.stats.kendalltau(dists_nd_all, dists_md_all)[0]
    metric_results.loc[p]['spat_kl']       = scipy.stats.entropy(dists_nd_all, dists_md_all)
# Out:
# CPU times: user 5min 43s, sys: 3.2 s, total: 5min 47s
# Wall time: 5min 43s

# %%
projection_paths
# Out:
# ['output/qtables-pcadtsne-p30-l0_000010-le1-ls0_10.csv',
#  'output/qtables-pcadtsne-p30-l0_000010-le1-ls1_00.csv',
#  'output/qtables-pcadtsne-p30-l0_000010-le1-ls10_00.csv',
#  'output/qtables-pcadtsne-p30-l0_000100-le1-ls0_10.csv',
#  'output/qtables-pcadtsne-p30-l0_000100-le1-ls1_00.csv',
#  'output/qtables-pcadtsne-p30-l0_000100-le1-ls10_00.csv',
#  'output/qtables-pcadtsne-p30-l0_001000-le1-ls0_10.csv',
#  'output/qtables-pcadtsne-p30-l0_001000-le1-ls1_00.csv',
#  'output/qtables-pcadtsne-p30-l0_001000-le1-ls10_00.csv',
#  'output/qtables-pcadtsne-p30-l0_010000-le1-ls0_10.csv',
#  'output/qtables-pcadtsne-p30-l0_010000-le1-ls1_00.csv',
#  'output/qtables-pcadtsne-p30-l0_010000-le1-ls10_00.csv']

# %%
pd.set_option('display.max_rows', None)
display(metric_results.T)
# Out:
#                  output/qtables-pcadtsne-p30-l0_000010-le1-ls0_10.csv  \
# stab_pearson                                              0.615065
# stab_spearman                                             0.519593
# stab_kendall                                              0.356556
# stab_kl                                                   0.611269
# stab_stress_n                                             0.570877
# stab_stress_s                                             0.769871
# spat_pearson                                              0.934869
# spat_spearman                                             0.902695
# spat_kendall                                              0.747374
# spat_kl                                                   0.106615
# spat_stress_n                                             0.067807
# spat_stress_s                                             0.130262
# spat_np_0.01                                              0.137500
# spat_np_0.02                                              0.270463
# spat_np_0.03                                              0.367000
# spat_np_0.04                                              0.440337
# spat_np_0.05                                              0.508009
# spat_np_0.06                                              0.536694
# spat_np_0.07                                              0.591678
# spat_np_0.08                                              0.643492
# spat_np_0.09                                              0.689028
# spat_np_0.1                                               0.730710
# spat_np_0.11                                              0.747756
# spat_np_0.12                                              0.764749
# spat_np_0.13                                              0.780616
# spat_np_0.14                                              0.794572
# spat_np_0.15                                              0.808729
# spat_np_0.16                                              0.816424
# spat_np_0.17                                              0.832352
# spat_np_0.18                                              0.847214
# spat_np_0.19                                              0.861716
# spat_np_0.2                                               0.875243
# spat_nh_1                                                 0.751111
# spat_nh_2                                                 0.740000
# spat_nh_3                                                 0.738843
# spat_nh_4                                                 0.734826
# spat_nh_5                                                 0.733389
# spat_nh_6                                                 0.728912
# spat_nh_7                                                 0.726409
# spat_nh_8                                                 0.723490
# spat_nh_9                                                 0.720031
# spat_nh_10                                                0.716153
# spat_nh_11                                                0.714116
# spat_nh_12                                                0.710984
# spat_nh_13                                                0.708835
# spat_nh_14                                                0.705496
# spat_nh_15                                                0.701991
# spat_nh_16                                                0.697622
# spat_nh_17                                                0.692688
# spat_nh_18                                                0.687924
# spat_nh_19                                                0.682237
# spat_nh_20                                                0.660590
# spat_trust_0.01                                           0.961920
# spat_trust_0.02                                           0.962861
# spat_trust_0.03                                           0.965955
# spat_trust_0.04                                           0.969093
# spat_trust_0.05                                           0.972324
# spat_trust_0.06                                           0.973817
# spat_trust_0.07                                           0.976438
# spat_trust_0.08                                           0.978681
# spat_trust_0.09                                           0.980420
# spat_trust_0.1                                            0.981839
# spat_trust_0.11                                           0.982500
# spat_trust_0.12                                           0.983472
# spat_trust_0.13                                           0.984132
# spat_trust_0.14                                           0.984764
# spat_trust_0.15                                           0.985340
# spat_trust_0.16                                           0.985715
# spat_trust_0.17                                           0.986297
# spat_trust_0.18                                           0.986767
# spat_trust_0.19                                           0.987227
# spat_trust_0.2                                            0.987526
# spat_cont_0.01                                            0.946865
# spat_cont_0.02                                            0.948947
# spat_cont_0.03                                            0.952950
# spat_cont_0.04                                            0.956979
# spat_cont_0.05                                            0.961610
# spat_cont_0.06                                            0.963696
# spat_cont_0.07                                            0.967037
# spat_cont_0.08                                            0.970124
# spat_cont_0.09                                            0.972830
# spat_cont_0.1                                             0.975172
# spat_cont_0.11                                            0.976324
# spat_cont_0.12                                            0.977751
# spat_cont_0.13                                            0.978978
# spat_cont_0.14                                            0.979966
# spat_cont_0.15                                            0.980841
# spat_cont_0.16                                            0.981322
# spat_cont_0.17                                            0.982093
# spat_cont_0.18                                            0.982878
# spat_cont_0.19                                            0.983395
# spat_cont_0.2                                             0.983800
#
#                  output/qtables-pcadtsne-p30-l0_000010-le1-ls1_00.csv  \
# stab_pearson                                              0.722568
# stab_spearman                                             0.523392
# stab_kendall                                              0.376090
# stab_kl                                                   0.627993
# stab_stress_n                                             3.615801
# stab_stress_s                                             0.554865
# spat_pearson                                              0.959189
# spat_spearman                                             0.937868
# spat_kendall                                              0.800195
# spat_kl                                                   0.131546
# spat_stress_n                                             0.078790
# spat_stress_s                                             0.081621
# spat_np_0.01                                              0.168889
# spat_np_0.02                                              0.291250
# spat_np_0.03                                              0.378806
# spat_np_0.04                                              0.446964
# spat_np_0.05                                              0.504537
# spat_np_0.06                                              0.530722
# spat_np_0.07                                              0.581887
# spat_np_0.08                                              0.629524
# spat_np_0.09                                              0.671832
# spat_np_0.1                                               0.712022
# spat_np_0.11                                              0.729408
# spat_np_0.12                                              0.740251
# spat_np_0.13                                              0.757663
# spat_np_0.14                                              0.771200
# spat_np_0.15                                              0.788133
# spat_np_0.16                                              0.796801
# spat_np_0.17                                              0.812727
# spat_np_0.18                                              0.826081
# spat_np_0.19                                              0.840919
# spat_np_0.2                                               0.855544
# spat_nh_1                                                 0.726944
# spat_nh_2                                                 0.732431
# spat_nh_3                                                 0.728611
# spat_nh_4                                                 0.728437
# spat_nh_5                                                 0.726333
# spat_nh_6                                                 0.724375
# spat_nh_7                                                 0.722401
# spat_nh_8                                                 0.721528
# spat_nh_9                                                 0.719383
# spat_nh_10                                                0.716514
# spat_nh_11                                                0.714848
# spat_nh_12                                                0.712766
# spat_nh_13                                                0.710053
# spat_nh_14                                                0.707371
# spat_nh_15                                                0.704241
# spat_nh_16                                                0.700790
# spat_nh_17                                                0.697051
# spat_nh_18                                                0.693704
# spat_nh_19                                                0.690095
# spat_nh_20                                                0.666715
# spat_trust_0.01                                           0.959337
# spat_trust_0.02                                           0.960155
# spat_trust_0.03                                           0.963624
# spat_trust_0.04                                           0.966817
# spat_trust_0.05                                           0.969866
# spat_trust_0.06                                           0.971392
# spat_trust_0.07                                           0.973900
# spat_trust_0.08                                           0.976221
# spat_trust_0.09                                           0.978211
# spat_trust_0.1                                            0.979848
# spat_trust_0.11                                           0.980576
# spat_trust_0.12                                           0.980864
# spat_trust_0.13                                           0.981286
# spat_trust_0.14                                           0.981768
# spat_trust_0.15                                           0.982400
# spat_trust_0.16                                           0.982763
# spat_trust_0.17                                           0.983407
# spat_trust_0.18                                           0.984008
# spat_trust_0.19                                           0.984658
# spat_trust_0.2                                            0.985202
# spat_cont_0.01                                            0.952917
# spat_cont_0.02                                            0.949821
# spat_cont_0.03                                            0.952215
# spat_cont_0.04                                            0.955706
# spat_cont_0.05                                            0.959422
# spat_cont_0.06                                            0.961026
# spat_cont_0.07                                            0.964293
# spat_cont_0.08                                            0.967312
# spat_cont_0.09                                            0.970047
# spat_cont_0.1                                             0.972481
# spat_cont_0.11                                            0.973451
# spat_cont_0.12                                            0.974921
# spat_cont_0.13                                            0.976294
# spat_cont_0.14                                            0.977487
# spat_cont_0.15                                            0.978754
# spat_cont_0.16                                            0.979276
# spat_cont_0.17                                            0.980373
# spat_cont_0.18                                            0.981475
# spat_cont_0.19                                            0.982438
# spat_cont_0.2                                             0.983334
#
#                  output/qtables-pcadtsne-p30-l0_000010-le1-ls10_00.csv  \
# stab_pearson                                              0.713397
# stab_spearman                                             0.505037
# stab_kendall                                              0.364174
# stab_kl                                                   0.646358
# stab_stress_n                                             3.186906
# stab_stress_s                                             0.573206
# spat_pearson                                              0.958941
# spat_spearman                                             0.938149
# spat_kendall                                              0.791875
# spat_kl                                                   0.139400
# spat_stress_n                                             0.086694
# spat_stress_s                                             0.082118
# spat_np_0.01                                              0.111667
# spat_np_0.02                                              0.191620
# spat_np_0.03                                              0.270528
# spat_np_0.04                                              0.337956
# spat_np_0.05                                              0.402870
# spat_np_0.06                                              0.433333
# spat_np_0.07                                              0.492141
# spat_np_0.08                                              0.547798
# spat_np_0.09                                              0.601354
# spat_np_0.1                                               0.652114
# spat_np_0.11                                              0.669547
# spat_np_0.12                                              0.682189
# spat_np_0.13                                              0.694004
# spat_np_0.14                                              0.709300
# spat_np_0.15                                              0.729285
# spat_np_0.16                                              0.739747
# spat_np_0.17                                              0.762449
# spat_np_0.18                                              0.784149
# spat_np_0.19                                              0.806985
# spat_np_0.2                                               0.832292
# spat_nh_1                                                 0.741667
# spat_nh_2                                                 0.745139
# spat_nh_3                                                 0.746065
# spat_nh_4                                                 0.742674
# spat_nh_5                                                 0.741833
# spat_nh_6                                                 0.739676
# spat_nh_7                                                 0.737520
# spat_nh_8                                                 0.736233
# spat_nh_9                                                 0.733534
# spat_nh_10                                                0.731236
# spat_nh_11                                                0.729381
# spat_nh_12                                                0.727280
# spat_nh_13                                                0.725620
# spat_nh_14                                                0.722867
# spat_nh_15                                                0.721602
# spat_nh_16                                                0.718559
# spat_nh_17                                                0.715629
# spat_nh_18                                                0.712739
# spat_nh_19                                                0.709313
# spat_nh_20                                                0.685451
# spat_trust_0.01                                           0.935245
# spat_trust_0.02                                           0.938258
# spat_trust_0.03                                           0.943435
# spat_trust_0.04                                           0.948209
# spat_trust_0.05                                           0.952757
# spat_trust_0.06                                           0.954977
# spat_trust_0.07                                           0.958959
# spat_trust_0.08                                           0.962533
# spat_trust_0.09                                           0.965669
# spat_trust_0.1                                            0.968512
# spat_trust_0.11                                           0.969689
# spat_trust_0.12                                           0.971299
# spat_trust_0.13                                           0.972795
# spat_trust_0.14                                           0.974361
# spat_trust_0.15                                           0.976081
# spat_trust_0.16                                           0.976883
# spat_trust_0.17                                           0.978619
# spat_trust_0.18                                           0.980107
# spat_trust_0.19                                           0.981580
# spat_trust_0.2                                            0.982877
# spat_cont_0.01                                            0.931946
# spat_cont_0.02                                            0.930457
# spat_cont_0.03                                            0.934643
# spat_cont_0.04                                            0.939518
# spat_cont_0.05                                            0.944947
# spat_cont_0.06                                            0.947284
# spat_cont_0.07                                            0.951790
# spat_cont_0.08                                            0.955741
# spat_cont_0.09                                            0.959549
# spat_cont_0.1                                             0.962882
# spat_cont_0.11                                            0.964130
# spat_cont_0.12                                            0.966221
# spat_cont_0.13                                            0.968177
# spat_cont_0.14                                            0.970314
# spat_cont_0.15                                            0.972589
# spat_cont_0.16                                            0.973719
# spat_cont_0.17                                            0.975866
# spat_cont_0.18                                            0.977975
# spat_cont_0.19                                            0.980025
# spat_cont_0.2                                             0.981823
#
#                  output/qtables-pcadtsne-p30-l0_000100-le1-ls0_10.csv  \
# stab_pearson                                              0.623204
# stab_spearman                                             0.395684
# stab_kendall                                              0.281085
# stab_kl                                                   0.729063
# stab_stress_n                                             0.517014
# stab_stress_s                                             0.753593
# spat_pearson                                              0.990162
# spat_spearman                                             0.941191
# spat_kendall                                              0.826745
# spat_kl                                                   0.049846
# spat_stress_n                                             0.010267
# spat_stress_s                                             0.019677
# spat_np_0.01                                              0.122500
# spat_np_0.02                                              0.263380
# spat_np_0.03                                              0.357139
# spat_np_0.04                                              0.438016
# spat_np_0.05                                              0.503333
# spat_np_0.06                                              0.532542
# spat_np_0.07                                              0.586481
# spat_np_0.08                                              0.638621
# spat_np_0.09                                              0.685286
# spat_np_0.1                                               0.728256
# spat_np_0.11                                              0.744978
# spat_np_0.12                                              0.759550
# spat_np_0.13                                              0.774034
# spat_np_0.14                                              0.785739
# spat_np_0.15                                              0.798560
# spat_np_0.16                                              0.806131
# spat_np_0.17                                              0.820861
# spat_np_0.18                                              0.835547
# spat_np_0.19                                              0.848256
# spat_np_0.2                                               0.860887
# spat_nh_1                                                 0.728750
# spat_nh_2                                                 0.728611
# spat_nh_3                                                 0.724722
# spat_nh_4                                                 0.721528
# spat_nh_5                                                 0.721028
# spat_nh_6                                                 0.719074
# spat_nh_7                                                 0.717381
# spat_nh_8                                                 0.716684
# spat_nh_9                                                 0.716373
# spat_nh_10                                                0.714486
# spat_nh_11                                                0.712487
# spat_nh_12                                                0.709120
# spat_nh_13                                                0.706667
# spat_nh_14                                                0.704246
# spat_nh_15                                                0.701750
# spat_nh_16                                                0.699323
# spat_nh_17                                                0.695931
# spat_nh_18                                                0.692060
# spat_nh_19                                                0.687683
# spat_nh_20                                                0.666014
# spat_trust_0.01                                           0.961561
# spat_trust_0.02                                           0.962921
# spat_trust_0.03                                           0.966246
# spat_trust_0.04                                           0.969047
# spat_trust_0.05                                           0.971941
# spat_trust_0.06                                           0.973440
# spat_trust_0.07                                           0.976029
# spat_trust_0.08                                           0.978339
# spat_trust_0.09                                           0.980165
# spat_trust_0.1                                            0.981743
# spat_trust_0.11                                           0.982365
# spat_trust_0.12                                           0.982604
# spat_trust_0.13                                           0.982832
# spat_trust_0.14                                           0.982926
# spat_trust_0.15                                           0.983162
# spat_trust_0.16                                           0.983363
# spat_trust_0.17                                           0.983647
# spat_trust_0.18                                           0.983888
# spat_trust_0.19                                           0.984001
# spat_trust_0.2                                            0.984122
# spat_cont_0.01                                            0.943780
# spat_cont_0.02                                            0.946744
# spat_cont_0.03                                            0.950850
# spat_cont_0.04                                            0.955790
# spat_cont_0.05                                            0.960485
# spat_cont_0.06                                            0.962565
# spat_cont_0.07                                            0.966395
# spat_cont_0.08                                            0.969660
# spat_cont_0.09                                            0.972444
# spat_cont_0.1                                             0.974861
# spat_cont_0.11                                            0.975877
# spat_cont_0.12                                            0.976022
# spat_cont_0.13                                            0.976349
# spat_cont_0.14                                            0.976560
# spat_cont_0.15                                            0.976914
# spat_cont_0.16                                            0.977345
# spat_cont_0.17                                            0.978039
# spat_cont_0.18                                            0.978597
# spat_cont_0.19                                            0.979238
# spat_cont_0.2                                             0.979701
#
#                  output/qtables-pcadtsne-p30-l0_000100-le1-ls1_00.csv  \
# stab_pearson                                              0.703191
# stab_spearman                                             0.492531
# stab_kendall                                              0.350411
# stab_kl                                                   0.640373
# stab_stress_n                                             0.452329
# stab_stress_s                                             0.593618
# spat_pearson                                              0.998185
# spat_spearman                                             0.967869
# spat_kendall                                              0.885374
# spat_kl                                                   0.063750
# spat_stress_n                                             0.006173
# spat_stress_s                                             0.003631
# spat_np_0.01                                              0.174722
# spat_np_0.02                                              0.281157
# spat_np_0.03                                              0.354417
# spat_np_0.04                                              0.418790
# spat_np_0.05                                              0.478657
# spat_np_0.06                                              0.507153
# spat_np_0.07                                              0.559005
# spat_np_0.08                                              0.606915
# spat_np_0.09                                              0.652049
# spat_np_0.1                                               0.695093
# spat_np_0.11                                              0.710643
# spat_np_0.12                                              0.728089
# spat_np_0.13                                              0.744306
# spat_np_0.14                                              0.759989
# spat_np_0.15                                              0.777608
# spat_np_0.16                                              0.787093
# spat_np_0.17                                              0.805333
# spat_np_0.18                                              0.822726
# spat_np_0.19                                              0.839048
# spat_np_0.2                                               0.855428
# spat_nh_1                                                 0.713472
# spat_nh_2                                                 0.718611
# spat_nh_3                                                 0.714583
# spat_nh_4                                                 0.714028
# spat_nh_5                                                 0.713250
# spat_nh_6                                                 0.711227
# spat_nh_7                                                 0.708790
# spat_nh_8                                                 0.709288
# spat_nh_9                                                 0.708596
# spat_nh_10                                                0.707806
# spat_nh_11                                                0.705758
# spat_nh_12                                                0.703171
# spat_nh_13                                                0.701357
# spat_nh_14                                                0.699425
# spat_nh_15                                                0.696481
# spat_nh_16                                                0.694219
# spat_nh_17                                                0.691626
# spat_nh_18                                                0.688873
# spat_nh_19                                                0.685607
# spat_nh_20                                                0.663812
# spat_trust_0.01                                           0.957136
# spat_trust_0.02                                           0.957635
# spat_trust_0.03                                           0.959959
# spat_trust_0.04                                           0.962914
# spat_trust_0.05                                           0.966068
# spat_trust_0.06                                           0.967520
# spat_trust_0.07                                           0.970178
# spat_trust_0.08                                           0.972741
# spat_trust_0.09                                           0.974797
# spat_trust_0.1                                            0.976667
# spat_trust_0.11                                           0.977489
# spat_trust_0.12                                           0.978589
# spat_trust_0.13                                           0.979681
# spat_trust_0.14                                           0.980731
# spat_trust_0.15                                           0.981963
# spat_trust_0.16                                           0.982579
# spat_trust_0.17                                           0.983654
# spat_trust_0.18                                           0.984685
# spat_trust_0.19                                           0.985736
# spat_trust_0.2                                            0.986582
# spat_cont_0.01                                            0.947939
# spat_cont_0.02                                            0.944074
# spat_cont_0.03                                            0.946660
# spat_cont_0.04                                            0.950752
# spat_cont_0.05                                            0.954768
# spat_cont_0.06                                            0.956624
# spat_cont_0.07                                            0.959988
# spat_cont_0.08                                            0.963233
# spat_cont_0.09                                            0.966341
# spat_cont_0.1                                             0.968968
# spat_cont_0.11                                            0.970010
# spat_cont_0.12                                            0.972072
# spat_cont_0.13                                            0.973887
# spat_cont_0.14                                            0.975691
# spat_cont_0.15                                            0.977420
# spat_cont_0.16                                            0.978299
# spat_cont_0.17                                            0.979947
# spat_cont_0.18                                            0.981467
# spat_cont_0.19                                            0.982881
# spat_cont_0.2                                             0.984099
#
#                  output/qtables-pcadtsne-p30-l0_000100-le1-ls10_00.csv  \
# stab_pearson                                              0.706072
# stab_spearman                                             0.496797
# stab_kendall                                              0.353244
# stab_kl                                                   0.633921
# stab_stress_n                                             0.433488
# stab_stress_s                                             0.587857
# spat_pearson                                              0.998301
# spat_spearman                                             0.974240
# spat_kendall                                              0.897935
# spat_kl                                                   0.069332
# spat_stress_n                                             0.006166
# spat_stress_s                                             0.003398
# spat_np_0.01                                              0.088194
# spat_np_0.02                                              0.185463
# spat_np_0.03                                              0.265333
# spat_np_0.04                                              0.333988
# spat_np_0.05                                              0.396281
# spat_np_0.06                                              0.423847
# spat_np_0.07                                              0.479144
# spat_np_0.08                                              0.532004
# spat_np_0.09                                              0.581033
# spat_np_0.1                                               0.627222
# spat_np_0.11                                              0.645183
# spat_np_0.12                                              0.666230
# spat_np_0.13                                              0.686751
# spat_np_0.14                                              0.707789
# spat_np_0.15                                              0.728894
# spat_np_0.16                                              0.740526
# spat_np_0.17                                              0.764231
# spat_np_0.18                                              0.787196
# spat_np_0.19                                              0.809489
# spat_np_0.2                                               0.832149
# spat_nh_1                                                 0.725833
# spat_nh_2                                                 0.738403
# spat_nh_3                                                 0.735741
# spat_nh_4                                                 0.737535
# spat_nh_5                                                 0.738444
# spat_nh_6                                                 0.735694
# spat_nh_7                                                 0.732341
# spat_nh_8                                                 0.731128
# spat_nh_9                                                 0.730093
# spat_nh_10                                                0.729250
# spat_nh_11                                                0.727992
# spat_nh_12                                                0.727049
# spat_nh_13                                                0.725224
# spat_nh_14                                                0.723671
# spat_nh_15                                                0.722028
# spat_nh_16                                                0.719948
# spat_nh_17                                                0.717296
# spat_nh_18                                                0.713403
# spat_nh_19                                                0.707895
# spat_nh_20                                                0.684403
# spat_trust_0.01                                           0.903353
# spat_trust_0.02                                           0.911806
# spat_trust_0.03                                           0.920512
# spat_trust_0.04                                           0.927900
# spat_trust_0.05                                           0.934882
# spat_trust_0.06                                           0.938028
# spat_trust_0.07                                           0.943910
# spat_trust_0.08                                           0.949073
# spat_trust_0.09                                           0.953484
# spat_trust_0.1                                            0.957574
# spat_trust_0.11                                           0.959599
# spat_trust_0.12                                           0.962891
# spat_trust_0.13                                           0.965952
# spat_trust_0.14                                           0.968867
# spat_trust_0.15                                           0.971732
# spat_trust_0.16                                           0.973080
# spat_trust_0.17                                           0.975629
# spat_trust_0.18                                           0.977953
# spat_trust_0.19                                           0.980098
# spat_trust_0.2                                            0.981992
# spat_cont_0.01                                            0.914595
# spat_cont_0.02                                            0.921628
# spat_cont_0.03                                            0.928558
# spat_cont_0.04                                            0.934646
# spat_cont_0.05                                            0.939869
# spat_cont_0.06                                            0.942396
# spat_cont_0.07                                            0.946870
# spat_cont_0.08                                            0.950859
# spat_cont_0.09                                            0.954944
# spat_cont_0.1                                             0.958530
# spat_cont_0.11                                            0.960017
# spat_cont_0.12                                            0.963127
# spat_cont_0.13                                            0.966006
# spat_cont_0.14                                            0.968808
# spat_cont_0.15                                            0.971501
# spat_cont_0.16                                            0.972832
# spat_cont_0.17                                            0.975434
# spat_cont_0.18                                            0.977770
# spat_cont_0.19                                            0.979939
# spat_cont_0.2                                             0.981840
#
#                  output/qtables-pcadtsne-p30-l0_001000-le1-ls0_10.csv  \
# stab_pearson                                              0.687574
# stab_spearman                                             0.505456
# stab_kendall                                              0.360359
# stab_kl                                                   0.644262
# stab_stress_n                                             0.393414
# stab_stress_s                                             0.624851
# spat_pearson                                              0.997800
# spat_spearman                                             0.964174
# spat_kendall                                              0.884536
# spat_kl                                                   0.045062
# spat_stress_n                                             0.004089
# spat_stress_s                                             0.004401
# spat_np_0.01                                              0.092500
# spat_np_0.02                                              0.202546
# spat_np_0.03                                              0.296167
# spat_np_0.04                                              0.383155
# spat_np_0.05                                              0.453272
# spat_np_0.06                                              0.485903
# spat_np_0.07                                              0.548958
# spat_np_0.08                                              0.605734
# spat_np_0.09                                              0.658385
# spat_np_0.1                                               0.706543
# spat_np_0.11                                              0.724605
# spat_np_0.12                                              0.746971
# spat_np_0.13                                              0.767343
# spat_np_0.14                                              0.785394
# spat_np_0.15                                              0.804115
# spat_np_0.16                                              0.813477
# spat_np_0.17                                              0.830597
# spat_np_0.18                                              0.847934
# spat_np_0.19                                              0.863930
# spat_np_0.2                                               0.879460
# spat_nh_1                                                 0.746944
# spat_nh_2                                                 0.734167
# spat_nh_3                                                 0.730046
# spat_nh_4                                                 0.726215
# spat_nh_5                                                 0.726667
# spat_nh_6                                                 0.726204
# spat_nh_7                                                 0.724464
# spat_nh_8                                                 0.722187
# spat_nh_9                                                 0.720633
# spat_nh_10                                                0.720125
# spat_nh_11                                                0.719053
# spat_nh_12                                                0.717292
# spat_nh_13                                                0.716400
# spat_nh_14                                                0.714514
# spat_nh_15                                                0.712185
# spat_nh_16                                                0.710269
# spat_nh_17                                                0.708023
# spat_nh_18                                                0.704174
# spat_nh_19                                                0.699715
# spat_nh_20                                                0.676236
# spat_trust_0.01                                           0.951715
# spat_trust_0.02                                           0.955034
# spat_trust_0.03                                           0.959640
# spat_trust_0.04                                           0.963907
# spat_trust_0.05                                           0.967990
# spat_trust_0.06                                           0.969915
# spat_trust_0.07                                           0.973281
# spat_trust_0.08                                           0.976086
# spat_trust_0.09                                           0.978367
# spat_trust_0.1                                            0.980281
# spat_trust_0.11                                           0.981095
# spat_trust_0.12                                           0.982148
# spat_trust_0.13                                           0.983209
# spat_trust_0.14                                           0.984146
# spat_trust_0.15                                           0.985220
# spat_trust_0.16                                           0.985711
# spat_trust_0.17                                           0.986555
# spat_trust_0.18                                           0.987414
# spat_trust_0.19                                           0.988245
# spat_trust_0.2                                            0.988858
# spat_cont_0.01                                            0.924843
# spat_cont_0.02                                            0.934452
# spat_cont_0.03                                            0.941583
# spat_cont_0.04                                            0.947385
# spat_cont_0.05                                            0.952746
# spat_cont_0.06                                            0.955158
# spat_cont_0.07                                            0.959933
# spat_cont_0.08                                            0.964083
# spat_cont_0.09                                            0.967774
# spat_cont_0.1                                             0.970876
# spat_cont_0.11                                            0.972124
# spat_cont_0.12                                            0.974793
# spat_cont_0.13                                            0.977122
# spat_cont_0.14                                            0.979137
# spat_cont_0.15                                            0.980976
# spat_cont_0.16                                            0.981879
# spat_cont_0.17                                            0.983333
# spat_cont_0.18                                            0.984674
# spat_cont_0.19                                            0.985776
# spat_cont_0.2                                             0.986703
#
#                  output/qtables-pcadtsne-p30-l0_001000-le1-ls1_00.csv  \
# stab_pearson                                              0.705314
# stab_spearman                                             0.507174
# ...
# spat_trust_0.08                                           0.955352
# spat_trust_0.09                                           0.959218
# spat_trust_0.1                                            0.962881
# spat_trust_0.11                                           0.964701
# spat_trust_0.12                                           0.967683
# spat_trust_0.13                                           0.970383
# spat_trust_0.14                                           0.972965
# spat_trust_0.15                                           0.975493
# spat_trust_0.16                                           0.976666
# spat_trust_0.17                                           0.978833
# spat_trust_0.18                                           0.980823
# spat_trust_0.19                                           0.982658
# spat_trust_0.2                                            0.984276
# spat_cont_0.01                                            0.910828
# spat_cont_0.02                                            0.920119
# spat_cont_0.03                                            0.927756
# spat_cont_0.04                                            0.934564
# spat_cont_0.05                                            0.940693
# spat_cont_0.06                                            0.943341
# spat_cont_0.07                                            0.948528
# spat_cont_0.08                                            0.952846
# spat_cont_0.09                                            0.956785
# spat_cont_0.1                                             0.960211
# spat_cont_0.11                                            0.961677
# spat_cont_0.12                                            0.964808
# spat_cont_0.13                                            0.967691
# spat_cont_0.14                                            0.970528
# spat_cont_0.15                                            0.973247
# spat_cont_0.16                                            0.974575
# spat_cont_0.17                                            0.977094
# spat_cont_0.18                                            0.979300
# spat_cont_0.19                                            0.981257
# spat_cont_0.2                                             0.983044
#
#                  output/qtables-pcadtsne-p30-l0_010000-le1-ls1_00.csv  \
# stab_pearson                                              0.706336
# stab_spearman                                             0.507342
# stab_kendall                                              0.358894
# stab_kl                                                   0.617777
# stab_stress_n                                             0.384283
# stab_stress_s                                             0.587328
# spat_pearson                                              0.998790
# spat_spearman                                             0.976920
# spat_kendall                                              0.909217
# spat_kl                                                   0.069007
# spat_stress_n                                             0.004627
# spat_stress_s                                             0.002419
# spat_np_0.01                                              0.080278
# spat_np_0.02                                              0.178935
# spat_np_0.03                                              0.261333
# spat_np_0.04                                              0.336865
# spat_np_0.05                                              0.400185
# spat_np_0.06                                              0.427153
# spat_np_0.07                                              0.484306
# spat_np_0.08                                              0.535337
# spat_np_0.09                                              0.583212
# spat_np_0.1                                               0.628056
# spat_np_0.11                                              0.647061
# spat_np_0.12                                              0.669974
# spat_np_0.13                                              0.692138
# spat_np_0.14                                              0.712756
# spat_np_0.15                                              0.734532
# spat_np_0.16                                              0.745481
# spat_np_0.17                                              0.768611
# spat_np_0.18                                              0.791037
# spat_np_0.19                                              0.812177
# spat_np_0.2                                               0.834664
# spat_nh_1                                                 0.733611
# spat_nh_2                                                 0.737014
# spat_nh_3                                                 0.735509
# spat_nh_4                                                 0.737222
# spat_nh_5                                                 0.733528
# spat_nh_6                                                 0.730949
# spat_nh_7                                                 0.727917
# spat_nh_8                                                 0.726597
# spat_nh_9                                                 0.725000
# spat_nh_10                                                0.724792
# spat_nh_11                                                0.723434
# spat_nh_12                                                0.722836
# spat_nh_13                                                0.721549
# spat_nh_14                                                0.721230
# spat_nh_15                                                0.718880
# spat_nh_16                                                0.715443
# spat_nh_17                                                0.711887
# spat_nh_18                                                0.707569
# spat_nh_19                                                0.702208
# spat_nh_20                                                0.678625
# spat_trust_0.01                                           0.900295
# spat_trust_0.02                                           0.910011
# spat_trust_0.03                                           0.919235
# spat_trust_0.04                                           0.926960
# spat_trust_0.05                                           0.934000
# spat_trust_0.06                                           0.937223
# spat_trust_0.07                                           0.943310
# spat_trust_0.08                                           0.948630
# spat_trust_0.09                                           0.953062
# spat_trust_0.1                                            0.957227
# spat_trust_0.11                                           0.959295
# spat_trust_0.12                                           0.962756
# spat_trust_0.13                                           0.965901
# spat_trust_0.14                                           0.968879
# spat_trust_0.15                                           0.971817
# spat_trust_0.16                                           0.973199
# spat_trust_0.17                                           0.975784
# spat_trust_0.18                                           0.978153
# spat_trust_0.19                                           0.980335
# spat_trust_0.2                                            0.982262
# spat_cont_0.01                                            0.910010
# spat_cont_0.02                                            0.919492
# spat_cont_0.03                                            0.927038
# spat_cont_0.04                                            0.933828
# spat_cont_0.05                                            0.939539
# spat_cont_0.06                                            0.942168
# spat_cont_0.07                                            0.947092
# spat_cont_0.08                                            0.951154
# spat_cont_0.09                                            0.955161
# spat_cont_0.1                                             0.958733
# spat_cont_0.11                                            0.960335
# spat_cont_0.12                                            0.963543
# spat_cont_0.13                                            0.966482
# spat_cont_0.14                                            0.969161
# spat_cont_0.15                                            0.971751
# spat_cont_0.16                                            0.973031
# spat_cont_0.17                                            0.975639
# spat_cont_0.18                                            0.977982
# spat_cont_0.19                                            0.980075
# spat_cont_0.2                                             0.982021
#
#                  output/qtables-pcadtsne-p30-l0_010000-le1-ls10_00.csv
# stab_pearson                                              0.706427
# stab_spearman                                             0.507496
# stab_kendall                                              0.358794
# stab_kl                                                   0.617644
# stab_stress_n                                             0.384051
# stab_stress_s                                             0.587145
# spat_pearson                                              0.998791
# spat_spearman                                             0.977024
# spat_kendall                                              0.909447
# spat_kl                                                   0.069672
# spat_stress_n                                             0.004628
# spat_stress_s                                             0.002418
# spat_np_0.01                                              0.081944
# spat_np_0.02                                              0.178056
# spat_np_0.03                                              0.260222
# spat_np_0.04                                              0.334742
# spat_np_0.05                                              0.396235
# spat_np_0.06                                              0.423250
# spat_np_0.07                                              0.479954
# spat_np_0.08                                              0.531607
# spat_np_0.09                                              0.579097
# spat_np_0.1                                               0.625062
# spat_np_0.11                                              0.644094
# spat_np_0.12                                              0.668089
# spat_np_0.13                                              0.690199
# spat_np_0.14                                              0.710489
# spat_np_0.15                                              0.733457
# spat_np_0.16                                              0.744415
# spat_np_0.17                                              0.766972
# spat_np_0.18                                              0.789609
# spat_np_0.19                                              0.811115
# spat_np_0.2                                               0.833329
# spat_nh_1                                                 0.730833
# spat_nh_2                                                 0.731806
# spat_nh_3                                                 0.735278
# spat_nh_4                                                 0.736076
# spat_nh_5                                                 0.731889
# spat_nh_6                                                 0.729537
# spat_nh_7                                                 0.727044
# spat_nh_8                                                 0.725764
# spat_nh_9                                                 0.724074
# spat_nh_10                                                0.723597
# spat_nh_11                                                0.723359
# spat_nh_12                                                0.722766
# spat_nh_13                                                0.722842
# spat_nh_14                                                0.721012
# spat_nh_15                                                0.717889
# spat_nh_16                                                0.714418
# spat_nh_17                                                0.710686
# spat_nh_18                                                0.706605
# spat_nh_19                                                0.701791
# spat_nh_20                                                0.678396
# spat_trust_0.01                                           0.897121
# spat_trust_0.02                                           0.907324
# spat_trust_0.03                                           0.917007
# spat_trust_0.04                                           0.925023
# spat_trust_0.05                                           0.932273
# spat_trust_0.06                                           0.935590
# spat_trust_0.07                                           0.941839
# spat_trust_0.08                                           0.947326
# spat_trust_0.09                                           0.951916
# spat_trust_0.1                                            0.956222
# spat_trust_0.11                                           0.958353
# spat_trust_0.12                                           0.961908
# spat_trust_0.13                                           0.965125
# spat_trust_0.14                                           0.968192
# spat_trust_0.15                                           0.971198
# spat_trust_0.16                                           0.972603
# spat_trust_0.17                                           0.975251
# spat_trust_0.18                                           0.977674
# spat_trust_0.19                                           0.979905
# spat_trust_0.2                                            0.981869
# spat_cont_0.01                                            0.911144
# spat_cont_0.02                                            0.919393
# spat_cont_0.03                                            0.926554
# spat_cont_0.04                                            0.933333
# spat_cont_0.05                                            0.938655
# spat_cont_0.06                                            0.941357
# spat_cont_0.07                                            0.946385
# spat_cont_0.08                                            0.950486
# spat_cont_0.09                                            0.954613
# spat_cont_0.1                                             0.958429
# spat_cont_0.11                                            0.959962
# spat_cont_0.12                                            0.963263
# spat_cont_0.13                                            0.966254
# spat_cont_0.14                                            0.968904
# spat_cont_0.15                                            0.971625
# spat_cont_0.16                                            0.972890
# spat_cont_0.17                                            0.975455
# spat_cont_0.18                                            0.977855
# spat_cont_0.19                                            0.979957
# spat_cont_0.2                                             0.981816

# %%
metric_results.to_csv('./metrics/results/{}_.csv'.format(dataset_id))
